# %% [markdown]
# # At start EDA only done on 1 State after that on all States

# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # EDA on Biometric Data

# %% [markdown]
# ### Importing Demography-1 file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
demo_1=pd.read_csv("/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_biometric/api_data_aadhar_biometric_0_500000.csv")
demo_1.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
demo_1.shape
# Out:
# (500000, 6)

# %%
demo_1['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
# ...

# %%
demo_1['new_date']=pd.to_datetime(demo_1['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
demo_1
# Out:
#               date              state      district  pincode  bio_age_5_17  \
# 0       01-03-2025            Haryana  Mahendragarh   123029           280
# 1       01-03-2025              Bihar     Madhepura   852121           144
# 2       01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3       01-03-2025              Bihar       Bhojpur   802158           256
# 4       01-03-2025         Tamil Nadu       Madurai   625514           271
# ...            ...                ...           ...      ...           ...
# 499995  19-09-2025              Delhi    West Delhi   110041           102
# 499996  19-09-2025              Delhi    West Delhi   110043             8
# 499997  19-09-2025              Delhi    West Delhi   110058             7
# 499998  19-09-2025                Goa     North Goa   403102             1
# 499999  19-09-2025                Goa     North Goa   403106             1
#
#         bio_age_17_  new_date
# 0               577  20250301
# ...

# %%
demo_1['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_1['new_date'].max())
print(demo_1['new_date'].min())
# Out:
# 20250919
# 20250301

# %% [markdown]
# ### Importing Demography-2 File

# %%
demo_2=pd.read_csv("/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_biometric/api_data_aadhar_biometric_500000_1000000.csv")
demo_2.head()
# Out:
#          date state   district  pincode  bio_age_5_17  bio_age_17_
# 0  19-09-2025   Goa  North Goa   403502             0            4
# 1  19-09-2025   Goa  North Goa   403508             1            4
# 2  19-09-2025   Goa  North Goa   403513             2            0
# 3  19-09-2025   Goa  North Goa   403527             2            2
# 4  19-09-2025   Goa  South Goa   403601             7            3

# %%
demo_2.shape
# Out:
# (500000, 6)

# %%
demo_2['state'].unique()
# Out:
# array(['Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Andhra Pradesh', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman & Diu', 'Delhi',
#        'Daman and Diu', 'West  Bengal',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Dadra & Nagar Haveli',
#        'West bengal', 'West Bangal', 'ODISHA', 'WEST BENGAL',
#        'andhra pradesh', 'odisha', 'Westbengal', 'WESTBENGAL'],
#       dtype=object)

# %%
demo_2['new_date']=pd.to_datetime(demo_2['date']).dt.strftime('%Y%m%d')
demo_2
# Out:
# /tmp/ipython-input-3808742326.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   demo_2['new_date']=pd.to_datetime(demo_2['date']).dt.strftime('%Y%m%d')
#               date   state   district  pincode  bio_age_5_17  bio_age_17_  \
# 0       19-09-2025     Goa  North Goa   403502             0            4
# 1       19-09-2025     Goa  North Goa   403508             1            4
# 2       19-09-2025     Goa  North Goa   403513             2            0
# 3       19-09-2025     Goa  North Goa   403527             2            2
# 4       19-09-2025     Goa  South Goa   403601             7            3
# ...            ...     ...        ...      ...           ...          ...
# 499995  07-11-2025  Kerala  Ernakulam   682020             1            6
# 499996  07-11-2025  Kerala  Ernakulam   682022             1            0
# ...

# %%
demo_2['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_2['new_date'].max())
print(demo_2['new_date'].min())
# Out:
# 20251107
# 20250919

# %%
demo_2.dtypes
# Out:
# date            object
# state           object
# district        object
# pincode          int64
# bio_age_5_17     int64
# bio_age_17_      int64
# new_date        object
# dtype: object

# %% [markdown]
# ### Importing Demography-3 file

# %%
demo_3=pd.read_csv("/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_biometric/api_data_aadhar_biometric_1000000_1500000.csv")
demo_3.head()
# Out:
#          date             state      district  pincode  bio_age_5_17  \
# 0  07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1  07-11-2025           Haryana   Yamunanagar   135001             1
# 2  07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3  07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4  07-11-2025  Himachal Pradesh      Bilaspur   174013             3
#
#    bio_age_17_
# 0            6
# 1            2
# 2            2
# 3            0
# 4            1

# %%
demo_3.shape
# Out:
# (500000, 6)

# %%
demo_3['state'].unique()
# Out:
# array(['Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Andaman & Nicobar Islands',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman & Diu',
#        'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Jammu & Kashmir',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Ladakh', 'West Bangal',
#        'West bengal', 'odisha',
#        'Dadra and Nagar Haveli and Daman and Diu', 'West  Bengal',
#        'WEST BENGAL', 'andhra pradesh', 'Westbengal', 'Chhatisgarh',
#        'ODISHA', 'WESTBENGAL', 'Uttaranchal'], dtype=object)

# %%
demo_3['new_date']=pd.to_datetime(demo_3['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
demo_3
# Out:
#               date             state      district  pincode  bio_age_5_17  \
# 0       07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1       07-11-2025           Haryana   Yamunanagar   135001             1
# 2       07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3       07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4       07-11-2025  Himachal Pradesh      Bilaspur   174013             3
# ...            ...               ...           ...      ...           ...
# 499995  08-12-2025           Gujarat      Vadodara   391150             3
# 499996  08-12-2025           Gujarat      Vadodara   391168            11
# 499997  08-12-2025           Gujarat      Vadodara   391170             0
# 499998  08-12-2025           Gujarat      Vadodara   391410             9
# 499999  08-12-2025           Gujarat      Vadodara   391530             3
#
#         bio_age_17_  new_date
# 0                 6  20251107
# ...

# %%
demo_3['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_3['new_date'].max())
print(demo_3['new_date'].min())
# Out:
# 20251208
# 20251107

# %% [markdown]
# ### Importing Demography-4 data

# %%
demo_4=pd.read_csv("/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_biometric/api_data_aadhar_biometric_1500000_1861108.csv")
demo_4.head()
# Out:
#          date          state       district  pincode  bio_age_5_17  \
# 0  08-12-2025  Uttar Pradesh      Moradabad   244411             4
# 1  08-12-2025  Uttar Pradesh      Moradabad   244601            14
# 2  08-12-2025  Uttar Pradesh  Muzaffarnagar   251002            22
# 3  08-12-2025  Uttar Pradesh  Muzaffarnagar   251202             4
# 4  08-12-2025  Uttar Pradesh  Muzaffarnagar   251319             4
#
#    bio_age_17_
# 0            2
# 1           19
# 2           37
# 3            4
# 4            7

# %%
demo_4.shape
# Out:
# (361108, 6)

# %%
demo_4['new_date']=pd.to_datetime(demo_4['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
demo_4
# Out:
#               date          state        district  pincode  bio_age_5_17  \
# 0       08-12-2025  Uttar Pradesh       Moradabad   244411             4
# 1       08-12-2025  Uttar Pradesh       Moradabad   244601            14
# 2       08-12-2025  Uttar Pradesh   Muzaffarnagar   251002            22
# 3       08-12-2025  Uttar Pradesh   Muzaffarnagar   251202             4
# 4       08-12-2025  Uttar Pradesh   Muzaffarnagar   251319             4
# ...            ...            ...             ...      ...           ...
# 361103  29-12-2025    West Bengal  Uttar Dinajpur   733201             4
# 361104  29-12-2025    West Bengal  Uttar Dinajpur   733213             0
# 361105  29-12-2025    West Bengal  West Midnapore   721304             0
# 361106  29-12-2025    West Bengal  West Midnapore   721451             2
# 361107  29-12-2025    West Bengal  West Midnapore   721457             0
#
#         bio_age_17_  new_date
# 0                 2  20251208
# ...

# %%
print(demo_4['new_date'].max())
print(demo_4['new_date'].min())
# Out:
# 20251229
# 20251208

# %% [markdown]
# ### Merging three dataset

# %%
#Merging all the files

df = pd.concat([demo_1, demo_2, demo_3, demo_4], axis=0, ignore_index=True)
df.shape
# Out:
# (1861108, 7)

# %%
df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_  new_date
# 0          577  20250301
# 1          369  20250301
# 2         1091  20250301
# 3          980  20250301
# 4          815  20250301

# %%
# checking shape of data
df.shape
# Out:
# (1861108, 7)

# %%
# checking null values in date
df['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
# count unique value of state
df['state'].nunique()
# Out:
# 57

# %%
df['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
# ...

# %% [markdown]
# # checking data consistency

# %%
df[df['state']=='Uttaranchal']
# Out:
#                date        state district  pincode  bio_age_5_17  bio_age_17_  \
# 374898   13-09-2025  Uttaranchal   Almora   263601             0            1
# 1431510  05-12-2025  Uttaranchal  Garhwal   249302             0            1
#
#          new_date
# 374898   20250913
# 1431510  20251205

# %% [markdown]
# ## Mappind state with correct name

# %%
df['state'] = df['state'].replace('Uttaranchal', 'Uttarakhand')

# %%
df['state'] = df['state'].replace('Tamilnadu', 'Tamil Nadu')

# %% [markdown]
# ## Mapping the state name

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove symbols like &, .
    x = re.sub(r'\s+', ' ', x).strip()  # remove extra spaces
    return x

# %%
state_mapping = {
    # West Bengal
    'west bengal': 'West Bengal',
    'west bangal': 'West Bengal',
    'westbengal': 'West Bengal',
    'west  bengal': 'West Bengal',
    'westbengal ': 'West Bengal',
    'west bengli':  'West Bengal',


    # Andhra Pradesh
    'andhra pradesh': 'Andhra Pradesh',

    # Odisha
    'odisha': 'Odisha',
    'orissa': 'Odisha',

    # Jammu & Kashmir
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',

    # Collapse all Dadra / Daman variants into ONE state
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'the dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',


    # Puducherry
    'puducherry': 'Puducherry',


    # Andaman & Nicobar Islands
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Puducherry
    'pondicherry': 'Puducherry',

    # Case-normalized direct matches
    'delhi': 'Delhi',
    'ladakh': 'Ladakh',
    'goa': 'Goa',
    'sikkim': 'Sikkim',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'punjab': 'Punjab',
    'kerala': 'Kerala',
    'haryana': 'Haryana',
    'gujarat': 'Gujarat',
    'tamil nadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'karnataka': 'Karnataka',
    'maharashtra': 'Maharashtra',
    'Nagpur': 'Maharashtra',
    'rajasthan': 'Rajasthan',
    'uttar pradesh': 'Uttar Pradesh',
    'madhya pradesh': 'Madhya Pradesh',
    'himachal pradesh': 'Himachal Pradesh',
    'arunachal pradesh': 'Arunachal Pradesh',
    'chhattisgarh': 'Chhattisgarh',
    'chhatisgarh' : 'Chhattisgarh',
    'jharkhand': 'Jharkhand',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'tripura': 'Tripura',
    'uttarakhand': 'Uttarakhand',
    'lakshadweep': 'Lakshadweep',
    'chandigarh': 'Chandigarh'
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries like numeric junk
df = df[~df['state'].astype(str).str.isnumeric()]

# Optional: check unmapped states
unmapped = df[df['state_clean'].isna()]['state'].unique()
print("Unmapped values:", unmapped)
# Out:
# Unmapped values: []

# %%
df.tail(20)
# Out:
#                date        state                    district  pincode  \
# 1861088  29-12-2025  West Bengal           South 24 Parganas   743375
# 1861089  29-12-2025  West Bengal           South 24 Parganas   743378
# 1861090  29-12-2025  West Bengal           South 24 Parganas   743384
# 1861091  29-12-2025  West Bengal           South 24 Parganas   743392
# 1861092  29-12-2025  West Bengal           South 24 Parganas   743502
# 1861093  29-12-2025  West Bengal              South Dinajpur   733126
# 1861094  29-12-2025  West Bengal              South Dinajpur   733140
# 1861095  29-12-2025  West Bengal              South Dinajpur   733145
# 1861096  29-12-2025  West Bengal              South Dinajpur   733153
# 1861097  29-12-2025  West Bengal              South Dinajpur   733155
# 1861098  29-12-2025  West Bengal  South Twenty Four Parganas   700084
# 1861099  29-12-2025  West Bengal  South Twenty Four Parganas   700145
# ...

# %%
df['state_clean'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Puducherry',
#        'Manipur', 'Sikkim', 'Tripura', 'Mizoram', 'Arunachal Pradesh',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Andaman and Nicobar Islands', 'Lakshadweep'], dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
#checking datatypes
df.dtypes
# Out:
# date            object
# state           object
# district        object
# pincode          int64
# bio_age_5_17     int64
# bio_age_17_      int64
# new_date        object
# state_clean     object
# dtype: object

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Filtering data on only one state (Bihar)

# %%
df_bihar=df[df['state_clean']=='Bihar']
df_bihar
# Out:
#                date  state        district  pincode  bio_age_5_17  \
# 1        01-03-2025  Bihar       Madhepura   852121           144
# 3        01-03-2025  Bihar         Bhojpur   802158           256
# 15       01-03-2025  Bihar        Vaishali   844504           426
# 56       01-03-2025  Bihar         Bhojpur   802164           165
# 72       01-03-2025  Bihar       Darbhanga   846003           438
# ...             ...    ...             ...      ...           ...
# 1857239  29-12-2025  Bihar        Vaishali   844131             1
# 1857240  29-12-2025  Bihar        Vaishali   844134             2
# 1857241  29-12-2025  Bihar        Vaishali   844502            12
# 1857242  29-12-2025  Bihar  West Champaran   845101            42
# 1857243  29-12-2025  Bihar  West Champaran   845307            26
#
#          bio_age_17_  new_date state_clean
# 1                369  20250301       Bihar
# 3                980  20250301       Bihar
# ...

# %%
df_bihar['district'].unique()
# Out:
# array(['Madhepura', 'Bhojpur', 'Vaishali', 'Darbhanga', 'Saharsa',
#        'Katihar', 'Patna', 'Supaul', 'Begusarai', 'Banka', 'Bhagalpur',
#        'Saran', 'Jehanabad', 'Muzaffarpur', 'West Champaran', 'Rohtas',
#        'Jamui', 'Gopalganj', 'Nalanda', 'Samastipur', 'Araria', 'Siwan',
#        'Aurangabad', 'Khagaria', 'Gaya', 'Purnia', 'Madhubani',
#        'Sheikhpura', 'Buxar', 'Purnea', 'Munger', 'East Champaran',
#        'Sitamarhi', 'Lakhisarai', 'Nawada', 'Kishanganj', 'Sheohar',
#        'Arwal', 'Kaimur (Bhabua)', 'Pashchim Champaran', 'Aurangabad(bh)',
#        'Monghyr', 'Samstipur', 'Sheikpura', 'Purba Champaran', 'Bhabua',
#        'Aurangabad(BH)'], dtype=object)

# %%
# df_bihar['district'] = df_bihar['district'].replace('Near University Thana', 'Darbhanga')

# %%
import re
import pandas as pd

def clean_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove (), ., etc
    x = re.sub(r'\s+', ' ', x).strip()
    return x

# %%
district_mapping_bihar = {

    # Champaran
    'purbi champaran': 'East Champaran',
    'purba champaran': 'East Champaran',
    'east champaran': 'East Champaran',

    'pashchim champaran': 'West Champaran',
    'west champaran': 'West Champaran',

    # Aurangabad
    'aurangabad bh': 'Aurangabad',
    'aurangabad bh ': 'Aurangabad',
    'aurangabad': 'Aurangabad',

    # Purnia
    'purnia': 'Purnia',
    'purnea': 'Purnia',

    # Kaimur
    'kaimur bhabua': 'Kaimur',
    'bhabua': 'Kaimur',

    # Munger
    'munger': 'Munger',
    'monghyr': 'Munger',

    # Samastipur
    'samastipur': 'Samastipur',
    'samstipur': 'Samastipur',

    # Sheikhpura
    'sheikhpura': 'Sheikhpura',
    'sheikpura': 'Sheikhpura',
    'monghyr' : 'Munger',

    # Normalized direct matches
    'sitamarhi': 'Sitamarhi',
    'madhubani': 'Madhubani',
    'bhagalpur': 'Bhagalpur',
    'patna': 'Patna',
    'muzaffarpur': 'Muzaffarpur',
    'gaya': 'Gaya',
    'saran': 'Saran',
    'vaishali': 'Vaishali',
    'jehanabad': 'Jehanabad',
    'jamui': 'Jamui',
    'gopalganj': 'Gopalganj',
    'saharsa': 'Saharsa',
    'arwal': 'Arwal',
    'katihar': 'Katihar',
    'siwan': 'Siwan',
    'lakhisarai': 'Lakhisarai',
    'banka': 'Banka',
    'nalanda': 'Nalanda',
    'araria': 'Araria',
    'darbhanga': 'Darbhanga',
    'nawada': 'Nawada',
    'begusarai': 'Begusarai',
    'bhojpur': 'Bhojpur',
    'buxar': 'Buxar',
    'khagaria': 'Khagaria',
    'kishanganj': 'Kishanganj',
    'madhepura': 'Madhepura',
    'rohtas': 'Rohtas',
    'sheohar': 'Sheohar',
    'supaul': 'Supaul'
}

# %%
df_bihar['district_clean'] = (
    df_bihar['district']
    .apply(clean_name)
    .map(district_mapping_bihar)
    .fillna(df_bihar['district'])
)
# Out:
# /tmp/ipython-input-828442334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['district_clean'] = (

# %%
# Remaining unmapped
df_bihar[df_bihar['district_clean'].isna()]['district'].unique()

# Count check
df_bihar['district_clean'].nunique()
# Out:
# 38

# %%
df_bihar
# Out:
#                date  state        district  pincode  bio_age_5_17  \
# 1        01-03-2025  Bihar       Madhepura   852121           144
# 3        01-03-2025  Bihar         Bhojpur   802158           256
# 15       01-03-2025  Bihar        Vaishali   844504           426
# 56       01-03-2025  Bihar         Bhojpur   802164           165
# 72       01-03-2025  Bihar       Darbhanga   846003           438
# ...             ...    ...             ...      ...           ...
# 1857239  29-12-2025  Bihar        Vaishali   844131             1
# 1857240  29-12-2025  Bihar        Vaishali   844134             2
# 1857241  29-12-2025  Bihar        Vaishali   844502            12
# 1857242  29-12-2025  Bihar  West Champaran   845101            42
# 1857243  29-12-2025  Bihar  West Champaran   845307            26
#
#          bio_age_17_  new_date state_clean  district_clean
# 1                369  20250301       Bihar       Madhepura
# ...

# %%
df_bihar['district_clean'].unique()
# Out:
# array(['Madhepura', 'Bhojpur', 'Vaishali', 'Darbhanga', 'Saharsa',
#        'Katihar', 'Patna', 'Supaul', 'Begusarai', 'Banka', 'Bhagalpur',
#        'Saran', 'Jehanabad', 'Muzaffarpur', 'West Champaran', 'Rohtas',
#        'Jamui', 'Gopalganj', 'Nalanda', 'Samastipur', 'Araria', 'Siwan',
#        'Aurangabad', 'Khagaria', 'Gaya', 'Purnia', 'Madhubani',
#        'Sheikhpura', 'Buxar', 'Munger', 'East Champaran', 'Sitamarhi',
#        'Lakhisarai', 'Nawada', 'Kishanganj', 'Sheohar', 'Arwal', 'Kaimur'],
#       dtype=object)

# %%
df_bihar['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_bihar['district_clean'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_bihar['pincode'].nunique()
# Out:
# 917

# %%
# df_bihar[['district_clean','pincode']].value_counts().reset_index(name='count')

# %%
pincode_check=df_bihar.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincode_count')

# %%
df_bihar[df_bihar['district_clean']=='Kaimur']['pincode'].unique()
# Out:
# array([821106, 821112, 821105, 821102, 821103, 821104, 802132, 821108,
#        821110, 821101, 821109, 821304, 802212, 802215, 821113, 821107,
#        802213, 821312, 802218, 821310])

# %%
pin_district_count = (
    df_bihar.groupby('pincode')['district_clean']
      .nunique()
      .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#      pincode  district_count
# 0     431010               1
# 1     800001               1
# 2     800002               1
# 3     800003               1
# 4     800004               1
# ..       ...             ...
# 912   855114               1
# 913   855115               2
# 914   855116               1
# 915   855117               2
# 916   855456               1
#
# [917 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
# Out:
#      pincode  district_count
# 45    801304               2
# 46    801305               2
# 58    802112               2
# 72    802128               2
# 73    802129               2
# ..       ...             ...
# 905   855101               4
# 907   855105               2
# 909   855107               3
# 913   855115               2
# 915   855117               2
#
# [202 rows x 2 columns]

# %%
df_flagged = df_bihar.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
df_flagged
# Out:
#              date  state   district  pincode  bio_age_5_17  bio_age_17_  \
# 0      01-03-2025  Bihar  Madhepura   852121           144          369
# 1      01-03-2025  Bihar    Saharsa   852210            58          118
# 2      01-03-2025  Bihar    Katihar   855105           684          838
# 3      01-03-2025  Bihar     Supaul   852123            43           87
# 4      01-03-2025  Bihar  Darbhanga   847306           330          381
# ...           ...    ...        ...      ...           ...          ...
# 26679  29-12-2025  Bihar  Sitamarhi   843328            24           28
# 26680  29-12-2025  Bihar  Sitamarhi   843334             0            1
# 26681  29-12-2025  Bihar      Siwan   841427             4            0
# 26682  29-12-2025  Bihar      Siwan   841436             5            8
# 26683  29-12-2025  Bihar   Vaishali   843102             6            4
#
#        new_date state_clean district_clean
# 0      20250301       Bihar      Madhepura
# ...

# %%
flagged_pincode_dominant=df_flagged.groupby(['district_clean', 'pincode'])[['bio_age_5_17','bio_age_17_']].sum().reset_index()
flagged_pincode_dominant.to_excel('flagged_pincode_dominant_bio.xlsx')

# %%
flagged_pincode_dominant['total_enroll']=flagged_pincode_dominant['bio_age_5_17']+flagged_pincode_dominant['bio_age_17_']
flagged_pincode_dominant.sort_values('pincode')
# Out:
#     district_clean  pincode  bio_age_5_17  bio_age_17_  total_enroll
# 284          Patna   801304           586          611          1197
# 260        Nalanda   801304          1055         1214          2269
# 261        Nalanda   801305          1292         1381          2673
# 285          Patna   801305           676          709          1385
# 73         Bhojpur   802112          1054          917          1971
# ..             ...      ...           ...          ...           ...
# 323         Purnia   855107          2075         2798          4873
# 324         Purnia   855115          1540         2099          3639
# 196     Kishanganj   855115          6712         8350         15062
# 197     Kishanganj   855117          9162        10649         19811
# 185        Katihar   855117             2           12            14
#
# [423 rows x 5 columns]

# %%
idx = flagged_pincode_dominant.groupby('pincode')['total_enroll'].idxmax()
df_filtered = flagged_pincode_dominant.loc[idx]
df_filtered
# Out:
#     district_clean  pincode  bio_age_5_17  bio_age_17_  total_enroll
# 260        Nalanda   801304          1055         1214          2269
# 261        Nalanda   801305          1292         1381          2673
# 82           Buxar   802112          1033         1151          2184
# 83           Buxar   802128          1353         1727          3080
# 84           Buxar   802129          1270         1880          3150
# ..             ...      ...           ...          ...           ...
# 194     Kishanganj   855101         14846        21651         36497
# 184        Katihar   855105          3919         5366          9285
# 195     Kishanganj   855107         12833        19060         31893
# 196     Kishanganj   855115          6712         8350         15062
# 197     Kishanganj   855117          9162        10649         19811
#
# [202 rows x 5 columns]

# %%
df_bihar['pin_multi_district_flag'] = (
    df_bihar.groupby('pincode')['district']
      .transform('nunique') > 1
)
# Out:
# /tmp/ipython-input-3362433199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['pin_multi_district_flag'] = (

# %%
pin_district_map = (
    df_bihar[df_bihar['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']
    .unique()
    .reset_index()
)

# %%
pin_district_map
# Out:
#      pincode                district_clean
# 0     801304              [Patna, Nalanda]
# 1     801305              [Nalanda, Patna]
# 2     802112              [Bhojpur, Buxar]
# 3     802128              [Buxar, Bhojpur]
# 4     802129              [Buxar, Bhojpur]
# ..       ...                           ...
# 305   855105             [Katihar, Purnia]
# 306   855107  [Kishanganj, Purnia, Araria]
# 307   855115          [Kishanganj, Purnia]
# 308   855117         [Kishanganj, Katihar]
# 309   855456              [East Champaran]
#
# [310 rows x 2 columns]

# %%
file_path='pin_district_bio_map.xlsx'
#pin_district_map.to_excel(file_path, index=False)

# %%
df_bihar['pin_multi_district_flag'].value_counts()
# Out:
# pin_multi_district_flag
# False    46675
# True     36723
# Name: count, dtype: int64

# %%
df_bihar['total_enroll']=df_bihar['bio_age_5_17']+df_bihar['bio_age_17_']
df_bihar
# Out:
# /tmp/ipython-input-4162557340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['total_enroll']=df_bihar['bio_age_5_17']+df_bihar['bio_age_17_']
#                date  state        district  pincode  bio_age_5_17  \
# 1        01-03-2025  Bihar       Madhepura   852121           144
# 3        01-03-2025  Bihar         Bhojpur   802158           256
# 15       01-03-2025  Bihar        Vaishali   844504           426
# 56       01-03-2025  Bihar         Bhojpur   802164           165
# 72       01-03-2025  Bihar       Darbhanga   846003           438
# ...             ...    ...             ...      ...           ...
# 1857239  29-12-2025  Bihar        Vaishali   844131             1
# ...

# %%
df_bihar['month']=df_bihar['new_date'].astype(str).str[4:6]
df_bihar
# Out:
# /tmp/ipython-input-3723542462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['month']=df_bihar['new_date'].astype(str).str[4:6]
#                date  state        district  pincode  bio_age_5_17  \
# 1        01-03-2025  Bihar       Madhepura   852121           144
# 3        01-03-2025  Bihar         Bhojpur   802158           256
# 15       01-03-2025  Bihar        Vaishali   844504           426
# 56       01-03-2025  Bihar         Bhojpur   802164           165
# 72       01-03-2025  Bihar       Darbhanga   846003           438
# ...             ...    ...             ...      ...           ...
# 1857239  29-12-2025  Bihar        Vaishali   844131             1
# ...

# %%
df_bihar_cleaned=df_bihar.drop(columns=['date','district','state'], axis=1)
df_bihar_cleaned
# Out:
#          pincode  bio_age_5_17  bio_age_17_  new_date state_clean  \
# 1         852121           144          369  20250301       Bihar
# 3         802158           256          980  20250301       Bihar
# 15        844504           426          958  20250301       Bihar
# 56        802164           165          311  20250301       Bihar
# 72        846003           438          859  20250301       Bihar
# ...          ...           ...          ...       ...         ...
# 1857239   844131             1            3  20251229       Bihar
# 1857240   844134             2            3  20251229       Bihar
# 1857241   844502            12            8  20251229       Bihar
# 1857242   845101            42           32  20251229       Bihar
# 1857243   845307            26           23  20251229       Bihar
#
#          district_clean  pin_multi_district_flag  total_enroll month
# 1             Madhepura                     True           513    03
# ...

# %%
df_bihar_dist_level=df_bihar_cleaned.groupby('district_clean')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
df_bihar_dist_level.shape
# Out:
# (38, 3)

# %%
df_bihar_dist_level
# Out:
#                 bio_age_5_17  bio_age_17_  total_enroll
# district_clean
# Araria                 72533        82911        155444
# Arwal                  12094        18610         30704
# Aurangabad             46591        50071         96662
# Banka                  49854        48373         98227
# Begusarai              72549        74659        147208
# Bhagalpur              72409        75905        148314
# Bhojpur                39485        57511         96996
# Buxar                  24831        32197         57028
# Darbhanga              93323       117057        210380
# East Champaran         95962       116436        212398
# Gaya                   85898        99274        185172
# Gopalganj              46818        56666        103484
# Jamui                  46558        35599         82157
# Jehanabad              15681        21749         37430
# Kaimur                 37554        40636         78190
# ...

# %%
df_bihar_dist_level=df_bihar_dist_level.sort_values('total_enroll', ascending=False).reset_index()
#df_bihar_dist_level.to_excel("df_bihar_dist_bio_level.xlsx")

# %%
df_bihar_dist_level1=df_bihar_dist_level.head(10)
df_bihar_dist_level1
# Out:
#    district_clean  bio_age_5_17  bio_age_17_  total_enroll
# 0       Madhubani        110514       127621        238135
# 1          Purnia        107060       126445        233505
# 2         Katihar         98243       119037        217280
# 3  East Champaran         95962       116436        212398
# 4       Darbhanga         93323       117057        210380
# 5           Patna         93322       115692        209014
# 6     Muzaffarpur         93075       115469        208544
# 7      Samastipur         93174       107186        200360
# 8            Gaya         85898        99274        185172
# 9       Sitamarhi         84925        97075        182000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_bihar_dist_level1[['bio_age_5_17','bio_age_17_']])
plt.show()

# %%
df_bihar_pincode_level=df_bihar_cleaned.groupby('pincode')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
df_bihar_pincode_level.shape
# Out:
# (917, 3)

# %%
df_bihar_pincode_level.sort_values('total_enroll', ascending=False).reset_index()
#df_bihar_pincode_level.to_excel("df_bihar_pincode_bio_level.xlsx")
# Out:
#      pincode  bio_age_5_17  bio_age_17_  total_enroll
# 0     855107         14909        21868         36777
# 1     855101         14848        21663         36511
# 2     854315         17230        17858         35088
# 3     854317         16548        18513         35061
# 4     855113         12906        13544         26450
# ..       ...           ...          ...           ...
# 912   824213             0            1             1
# 913   803218             0            1             1
# 914   805236             0            1             1
# 915   800029             1            0             1
# 916   801111             1            0             1
#
# [917 rows x 4 columns]

# %%
df_bihar_pincode_level=df_bihar_pincode_level.sort_values('total_enroll', ascending=False).reset_index()

# %%
df_bihar_pincode_level1=df_bihar_pincode_level.head(10)
df_bihar_pincode_level1
# Out:
#    pincode  bio_age_5_17  bio_age_17_  total_enroll
# 0   855107         14909        21868         36777
# 1   855101         14848        21663         36511
# 2   854315         17230        17858         35088
# 3   854317         16548        18513         35061
# 4   855113         12906        13544         26450
# 5   854304          9954        14151         24105
# 6   854318         10404        13586         23990
# 7   854311         12658        11238         23896
# 8   843302         10976        12393         23369
# 9   855108          7773        14750         22523

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_bihar_pincode_level1[['bio_age_5_17','bio_age_17_','total_enroll']])
plt.show()

# %%
bihar_month_enroll_trend=df_bihar_cleaned.groupby('month')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
bihar_month_enroll_trend
# Out:
#        bio_age_5_17  bio_age_17_  total_enroll
# month
# 03           324179       439330        763509
# 04           419994       375725        795719
# 05           283915       268284        552199
# 06           239119       255338        494457
# 07           253037       351024        604061
# 09           145416       226685        372101
# 10           109493       160656        270149
# 11           151867       253099        404966
# 12           281121       359305        640426

# %%
#bihar_month_enroll_trend.to_excel("df_bihar_month_bio_level.xlsx")

# %%
sns.lineplot(data=bihar_month_enroll_trend)
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# # **State_Wise_EDA**

# %%
import os
import pandas as pd
import re

# ==========================================
# 1. CONFIGURATION
# ==========================================
# Input Folder (Biometric Data)
input_folder = '/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_biometric/'

# Output Folder (Where to save results)
output_folder = '/content/drive/MyDrive/UIDAI Hackathon 2026/State_Wise_Biometric_EDA/'
os.makedirs(output_folder, exist_ok=True)

# --- A. OFFICIAL DISTRICTS DICTIONARY (Strict Source of Truth) ---
official_districts = {
    "Andhra Pradesh": ["Alluri Sitharama Raju", "Anakapalli", "Ananthapuramu", "Annamayya", "Bapatla", "Chittoor", "Dr. B.R. Ambedkar Konaseema", "East Godavari", "Eluru", "Guntur", "Kakinada", "Krishna", "Kurnool", "Nandyal", "NTR", "Palnadu", "Parvathipuram Manyam", "Prakasam", "Sri Potti Sriramulu Nellore", "Sri Sathya Sai", "Srikakulam", "Tirupati", "Visakhapatnam", "Vizianagaram", "West Godavari", "YSR Kadapa"],
    "Arunachal Pradesh": ["Anjaw", "Changlang", "Dibang Valley", "East Kameng", "East Siang", "Itanagar Capital Complex", "Kamle", "Kra Daadi", "Kurung Kumey", "Lepa Rada", "Lohit", "Longding", "Lower Dibang Valley", "Lower Siang", "Lower Subansiri", "Namsai", "Pakke Kessang", "Papum Pare", "Shi Yomi", "Siang", "Tawang", "Tirap", "Upper Siang", "Upper Subansiri", "West Kameng", "West Siang"],
    "Assam": ["Bajali", "Baksa", "Barpeta", "Biswanath", "Bongaigaon", "Cachar", "Charaideo", "Chirang", "Darrang", "Dhemaji", "Dhubri", "Dibrugarh", "Dima Hasao", "Goalpara", "Golaghat", "Hailakandi", "Hojai", "Jorhat", "Kamrup", "Kamrup Metropolitan", "Karbi Anglong", "Karimganj", "Kokrajhar", "Lakhimpur", "Majuli", "Morigaon", "Nagaon", "Nalbari", "Sivasagar", "Sonitpur", "South Salmara-Mankachar", "Tamulpur", "Tinsukia", "Udalguri", "West Karbi Anglong"],
    "Bihar": ["Araria", "Arwal", "Aurangabad", "Banka", "Begusarai", "Bhagalpur", "Bhojpur", "Buxar", "Darbhanga", "East Champaran", "Gaya", "Gopalganj", "Jamui", "Jehanabad", "Kaimur", "Katihar", "Khagaria", "Kishanganj", "Lakhisarai", "Madhepura", "Madhubani", "Munger", "Muzaffarpur", "Nalanda", "Nawada", "Patna", "Purnia", "Rohtas", "Saharsa", "Samastipur", "Saran", "Sheikhpura", "Sheohar", "Sitamarhi", "Siwan", "Supaul", "Vaishali", "West Champaran"],
    "Chhattisgarh": ["Balod", "Baloda Bazar", "Balrampur", "Bastar", "Bemetara", "Bijapur", "Bilaspur", "Dantewada", "Dhamtari", "Durg", "Gariaband", "Gaurela-Pendra-Marwahi", "Janjgir-Champa", "Jashpur", "Kabirdham", "Kanker", "Khairagarh-Chhuikhadan-Gandai", "Kondagaon", "Korba", "Koriya", "Mahasamund", "Manendragarh-Chirmiri-Bharatpur", "Mohla-Manpur-Ambagarh Chowki", "Mungeli", "Narayanpur", "Raigarh", "Raipur", "Rajnandgaon", "Sakti", "Sarangarh-Bilaigarh", "Sukma", "Surajpur", "Surguja"],
    "Goa": ["North Goa", "South Goa"],
    "Gujarat": ["Ahmedabad", "Amreli", "Anand", "Aravalli", "Banaskantha", "Bharuch", "Bhavnagar", "Botad", "Chhota Udepur", "Dahod", "Dang", "Devbhoomi Dwarka", "Gandhinagar", "Gir Somnath", "Jamnagar", "Junagadh", "Kheda", "Kutch", "Mahisagar", "Mehsana", "Morbi", "Narmada", "Navsari", "Panchmahal", "Patan", "Porbandar", "Rajkot", "Sabarkantha", "Surat", "Surendranagar", "Tapi", "Vadodara", "Valsad"],
    "Haryana": ["Ambala", "Bhiwani", "Charkhi Dadri", "Faridabad", "Fatehabad", "Gurugram", "Hisar", "Jhajjar", "Jind", "Kaithal", "Karnal", "Kurukshetra", "Mahendragarh", "Nuh", "Palwal", "Panchkula", "Panipat", "Rewari", "Rohtak", "Sirsa", "Sonipat", "Yamunanagar"],
    "Himachal Pradesh": ["Bilaspur", "Chamba", "Hamirpur", "Kangra", "Kinnaur", "Kullu", "Lahaul and Spiti", "Mandi", "Shimla", "Sirmaur", "Solan", "Una"],
    "Jharkhand": ["Bokaro", "Chatra", "Deoghar", "Dhanbad", "Dumka", "East Singhbhum", "Garhwa", "Giridih", "Godda", "Gumla", "Hazaribagh", "Jamtara", "Khunti", "Koderma", "Latehar", "Lohardaga", "Pakur", "Palamu", "Ramgarh", "Ranchi", "Sahibganj", "Seraikela Kharsawan", "Simdega", "West Singhbhum"],
    "Karnataka": ["Bagalkote", "Ballari", "Belagavi", "Bengaluru Rural", "Bengaluru Urban", "Bidar", "Chamarajanagar", "Chikkaballapura", "Chikkamagaluru", "Chitradurga", "Dakshina Kannada", "Davanagere", "Dharwad", "Gadag", "Hassan", "Haveri", "Kalaburagi", "Kodagu", "Kolar", "Koppal", "Mandya", "Mysuru", "Raichur", "Ramanagara", "Shivamogga", "Tumakuru", "Udupi", "Uttara Kannada", "Vijayanagara", "Vijayapura", "Yadgir"],
    "Kerala": ["Alappuzha", "Ernakulam", "Idukki", "Kannur", "Kasaragod", "Kollam", "Kottayam", "Kozhikode", "Malappuram", "Palakkad", "Pathanamthitta", "Thiruvananthapuram", "Thrissur", "Wayanad"],
    "Madhya Pradesh": ["Agar Malwa", "Alirajpur", "Anuppur", "Ashoknagar", "Balaghat", "Barwani", "Betul", "Bhind", "Bhopal", "Burhanpur", "Chhatarpur", "Chhindwara", "Damoh", "Datia", "Dewas", "Dhar", "Dindori", "Guna", "Gwalior", "Harda", "Narmadapuram", "Indore", "Jabalpur", "Jhabua", "Katni", "Khandwa", "Khargone", "Maihar", "Mandla", "Mandsaur", "Mauganj", "Morena", "Narsinghpur", "Neemuch", "Niwari", "Pandhurna", "Panna", "Raisen", "Rajgarh", "Ratlam", "Rewa", "Sagar", "Satna", "Sehore", "Seoni", "Shahdol", "Shajapur", "Sheopur", "Shivpuri", "Sidhi", "Singrauli", "Tikamgarh", "Ujjain", "Umaria", "Vidisha"],
    "Maharashtra": ["Ahmednagar", "Akola", "Amravati", "Aurangabad", "Beed", "Bhandara", "Buldhana", "Chandrapur", "Dhule", "Gadchiroli", "Gondia", "Hingoli", "Jalgaon", "Jalna", "Kolhapur", "Latur", "Mumbai City", "Mumbai Suburban", "Nagpur", "Nanded", "Nandurbar", "Nashik", "Osmanabad", "Palghar", "Parbhani", "Pune", "Raigad", "Ratnagiri", "Sangli", "Satara", "Sindhudurg", "Solapur", "Thane", "Wardha", "Washim", "Yavatmal"],
    "Manipur": ["Bishnupur", "Chandel", "Churachandpur", "Imphal East", "Imphal West", "Jiribam", "Kakching", "Kamjong", "Kangpokpi", "Noney", "Pherzawl", "Senapati", "Tamenglong", "Tengnoupal", "Thoubal", "Ukhrul"],
    "Meghalaya": ["East Garo Hills", "East Jaintia Hills", "East Khasi Hills", "Eastern West Khasi Hills", "North Garo Hills", "Ri Bhoi", "South Garo Hills", "South West Garo Hills", "South West Khasi Hills", "West Garo Hills", "West Jaintia Hills", "West Khasi Hills"],
    "Mizoram": ["Aizawl", "Champhai", "Hnahthial", "Khawzawl", "Kolasib", "Lawngtlai", "Lunglei", "Mamit", "Saiha", "Saitual", "Serchhip"],
    "Nagaland": ["Chumoukedima", "Dimapur", "Kiphire", "Kohima", "Longleng", "Mokokchung", "Mon", "Niuland", "Noklak", "Peren", "Phek", "Shamator", "Tseminyu", "Tuensang", "Wokha", "Zunheboto"],
    "Odisha": ["Angul", "Balangir", "Balasore", "Bargarh", "Bhadrak", "Boudh", "Cuttack", "Deogarh", "Dhenkanal", "Gajapati", "Ganjam", "Jagatsinghpur", "Jajpur", "Jharsuguda", "Kalahandi", "Kandhamal", "Kendrapara", "Kendujhar", "Khordha", "Koraput", "Malkangiri", "Mayurbhanj", "Nabarangpur", "Nayagarh", "Nuapada", "Puri", "Rayagada", "Sambalpur", "Subarnapur", "Sundargarh"],
    "Punjab": ["Amritsar", "Barnala", "Bathinda", "Faridkot", "Fatehgarh Sahib", "Fazilka", "Ferozepur", "Gurdaspur", "Hoshiarpur", "Jalandhar", "Kapurthala", "Ludhiana", "Malerkotla", "Mansa", "Moga", "Mohali", "Muktsar", "Nawanshahr", "Pathankot", "Patiala", "Rupnagar", "Sangrur", "Tarn Taran"],
    "Rajasthan": ["Ajmer", "Alwar", "Anupgarh", "Balotra", "Banswara", "Baran", "Barmer", "Beawar", "Bharatpur", "Bhilwara", "Bikaner", "Bundi", "Chittorgarh", "Churu", "Dausa", "Deeg", "Dholpur", "Didwana-Kuchaman", "Dudu", "Dungarpur", "Gangapur City", "Hanumangarh", "Jaipur", "Jaipur Rural", "Jaisalmer", "Jalore", "Jhalawar", "Jhunjhunu", "Jodhpur", "Jodhpur Rural", "Karauli", "Kekri", "Khairthal-Tijara", "Kota", "Kotputli-Behror", "Nagaur", "Neem Ka Thana", "Pali", "Phalodi", "Pratapgarh", "Rajsamand", "Salumbar", "Sanchore", "Sawai Madhopur", "Shahpura", "Sikar", "Sirohi", "Sri Ganganagar", "Tonk", "Udaipur"],
    "Sikkim": ["Gangtok", "Gyalshing", "Mangan", "Namchi", "Pakyong", "Soreng"],
    "Tamil Nadu": ["Ariyalur", "Chengalpattu", "Chennai", "Coimbatore", "Cuddalore", "Dharmapuri", "Dindigul", "Erode", "Kallakurichi", "Kancheepuram", "Kanniyakumari", "Karur", "Krishnagiri", "Madurai", "Mayiladuthurai", "Nagapattinam", "Namakkal", "Nilgiris", "Perambalur", "Pudukkottai", "Ramanathapuram", "Ranipet", "Salem", "Sivaganga", "Tenkasi", "Thanjavur", "Theni", "Thoothukudi", "Tiruchirappalli", "Tirunelveli", "Tirupathur", "Tiruppur", "Tiruvallur", "Tiruvannamalai", "Tiruvarur", "Vellore", "Viluppuram", "Virudhunagar"],
    "Telangana": ["Adilabad", "Bhadradri Kothagudem", "Hanumakonda", "Hyderabad", "Jagtial", "Jangaon", "Jayashankar Bhupalpally", "Jogulamba Gadwal", "Kamareddy", "Karimnagar", "Khammam", "Komaram Bheem Asifabad", "Mahabubabad", "Mahabubnagar", "Mancherial", "Medak", "Medchal-Malkajgiri", "Mulugu", "Nagarkurnool", "Nalgonda", "Narayanpet", "Nirmal", "Nizamabad", "Peddapalli", "Rajanna Sircilla", "Ranga Reddy", "Sangareddy", "Siddipet", "Suryapet", "Vikarabad", "Wanaparthy", "Warangal", "Yadadri Bhuvanagiri"],
    "Tripura": ["Dhalai", "Gomati", "Khowai", "North Tripura", "Sepahijala", "South Tripura", "Unakoti", "West Tripura"],
    "Uttar Pradesh": ["Agra", "Aligarh", "Ambedkar Nagar", "Amethi", "Amroha", "Auraiva", "Ayodhya", "Azamgarh", "Baghpat", "Bahraich", "Ballia", "Balrampur", "Banda", "Barabanki", "Bareilly", "Basti", "Bhadohi", "Bijnor", "Budaun", "Bulandshahr", "Chandauli", "Chitrakoot", "Deoria", "Etah", "Etawah", "Farrukhabad", "Fatehpur", "Firozabad", "Gautam Buddha Nagar", "Ghaziabad", "Ghazipur", "Gonda", "Gorakhpur", "Hamirpur", "Hapur", "Hardoi", "Hathras", "Jalaun", "Jaunpur", "Jhansi", "Kannauj", "Kanpur Dehat", "Kanpur Nagar", "Kasganj", "Kaushambi", "Kheri", "Kushinagar", "Lalitpur", "Lucknow", "Maharajganj", "Mahoba", "Mainpuri", "Mathura", "Mau", "Meerut", "Mirzapur", "Moradabad", "Muzaffarnagar", "Pilibhit", "Pratapgarh", "Prayagraj", "Raebareli", "Rampur", "Saharanpur", "Sambhal", "Sant Kabir Nagar", "Shahjahanpur", "Shamli", "Shravasti", "Siddharthnagar", "Sitapur", "Sonbhadra", "Sultanpur", "Unnao", "Varanasi"],
    "Uttarakhand": ["Almora", "Bageshwar", "Chamoli", "Champawat", "Dehradun", "Haridwar", "Nainital", "Pauri Garhwal", "Pithoragarh", "Rudraprayag", "Tehri Garhwal", "Udham Singh Nagar", "Uttarkashi"],
    "West Bengal": ["Alipurduar", "Bankura", "Birbhum", "Cooch Behar", "Dakshin Dinajpur", "Darjeeling", "Hooghly", "Howrah", "Jalpaiguri", "Jhargram", "Kalimpong", "Kolkata", "Malda", "Murshidabad", "Nadia", "North 24 Parganas", "Paschim Bardhaman", "Paschim Medinipur", "Purba Bardhaman", "Purba Medinipur", "Purulia", "South 24 Parganas", "Uttar Dinajpur"],
    "Jammu and Kashmir": ["Anantnag", "Bandipora", "Baramulla", "Budgam", "Doda", "Ganderbal", "Jammu", "Kathua", "Kishtwar", "Kulgam", "Kupwara", "Poonch", "Pulwama", "Rajouri", "Ramban", "Reasi", "Samba", "Shopian", "Srinagar", "Udhampur"],
    "Ladakh": ["Kargil", "Leh"],
    "Delhi": ["Central Delhi", "East Delhi", "New Delhi", "North Delhi", "North East Delhi", "North West Delhi", "Shahdara", "South Delhi", "South East Delhi", "South West Delhi", "West Delhi"],
    "Puducherry": ["Karaikal", "Mahe", "Puducherry", "Yanam"],
    "Dadra and Nagar Haveli and Daman and Diu": ["Dadra and Nagar Haveli", "Daman", "Diu"],
    "Chandigarh": ["Chandigarh"],
    "Andaman and Nicobar Islands": ["Nicobar", "North and Middle Andaman", "South Andaman"],
    "Lakshadweep": ["Lakshadweep"]
}

# --- B. MANUAL CORRECTIONS DICTIONARY ---
manual_corrections = {
    "Andhra Pradesh": {
        "spsr nellore": "Sri Potti Sriramulu Nellore", "nellore": "Sri Potti Sriramulu Nellore",
        "visakhapatanam": "Visakhapatnam", "anantapur": "Ananthapuramu", "ananthapur": "Ananthapuramu",
        "cuddapah": "YSR Kadapa", "y. s. r": "YSR Kadapa", "n. t. r": "NTR",
        "dr. b. r. ambedkar konaseema": "Dr. B.R. Ambedkar Konaseema",
        # Fix: Remap Telangana districts found in AP data
        "mahabub nagar": "Mahabubnagar", "mahbubnagar": "Mahabubnagar",
        "rangareddi": "Ranga Reddy", "k.v.rangareddy": "Ranga Reddy", "k.v. rangareddy": "Ranga Reddy",
        "karim nagar": "Karimnagar", "medak": "Medak", "nalgonda": "Nalgonda", "warangal": "Warangal",
        "adilabad": "Adilabad", "hyderabad": "Hyderabad", "khammam": "Khammam", "nizamabad": "Nizamabad"
    },
    "Maharashtra": {
        "ahmadnagar": "Ahmednagar", "ahmed nagar": "Ahmednagar", "ahilyanagar": "Ahmednagar",
        "washim *": "Washim", "nandurbar *": "Nandurbar", "buldana": "Buldhana",
        "gondiya": "Gondia", "gondiya *": "Gondia", "bid": "Beed",
        "raigarh": "Raigad", "raigarh(mh)": "Raigad",
        "chatrapati sambhaji nagar": "Aurangabad", "chhatrapati sambhajinagar": "Aurangabad",
        "mumbai": "Mumbai City", "mumbai(sub urban)": "Mumbai Suburban", "mumbai sub urban": "Mumbai Suburban", "mumbai suburban": "Mumbai Suburban"
    },
    "Bihar": {
        "purbi champaran": "East Champaran", "purba champaran": "East Champaran", "east champaran (motihari)": "East Champaran",
        "pashchim champaran": "West Champaran",
        "aurangabad(bh)": "Aurangabad", "purnea": "Purnia", "sheikpura": "Sheikhpura",
        "bhabua": "Kaimur", "kaimur (bhabua)": "Kaimur", "monghyr": "Munger", "samstipur": "Samastipur"
    }
}

# ==========================================
# 2. HELPER: CLEAN & VALIDATE (STRICT)
# ==========================================
def clean_and_validate_district(state_name, district_raw):
    if pd.isna(district_raw): return None
    clean = str(district_raw).lower().strip()
    clean = clean.replace('*', '').strip()
    clean = re.sub(r'\s+', ' ', clean)

    if state_name in manual_corrections:
        if clean in manual_corrections[state_name]:
            clean = manual_corrections[state_name][clean]

    final_name = clean.title()
    if "mumbai" in clean and "sub" in clean: final_name = "Mumbai Suburban"
    if "n.t.r" in clean or "ntr" in clean: final_name = "NTR"

    official_list = official_districts.get(state_name, [])

    if final_name in official_list:
        return final_name
    else:
        return None

# ==========================================
# 3. LOAD BIOMETRIC DATA
# ==========================================
print("Loading Biometric Data...")
all_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]
df_list = []
for file in all_files:
    try:
        temp = pd.read_csv(os.path.join(input_folder, file))
        df_list.append(temp)
    except: pass

if not df_list:
    raise Exception("No CSV files found in Biometric folder!")

df_bio = pd.concat(df_list, ignore_index=True)
print(f"Loaded {len(df_bio)} rows.")

# --- DYNAMIC COLUMN DETECTION ---
# Find columns that look like 'bio_age_...' automatically
bio_cols = [c for c in df_bio.columns if 'bio_age_' in c]
print(f"Detected Biometric Columns: {bio_cols}")

# Create a cleaned 'state_clean' column (Generic cleanup)
def simple_state_clean(x):
    if pd.isna(x): return "Unknown"
    x = str(x).lower().strip()
    x = re.sub(r'[^\w\s]', '', x) # remove punctuation

    # Quick fix for common state typos before processing
    mapping = {
        "andhra pradesh": "Andhra Pradesh", "maharashtra": "Maharashtra", "bihar": "Bihar",
        "west bengal": "West Bengal", "westbengal": "West Bengal", "odisha": "Odisha", "orissa": "Odisha"
    }
    return mapping.get(x, x.title())

df_bio['state_clean'] = df_bio['state'].apply(simple_state_clean)

# ==========================================
# 4. PROCESSING LOOP (STRICT FILTER)
# ==========================================
def process_biometric_state(target_state):
    print(f"Processing: {target_state}...")

    # Filter
    state_df = df_bio[df_bio['state_clean'] == target_state].copy()
    if state_df.empty: return None

    # Clean Districts & Strict Filter
    state_df['district_clean'] = state_df.apply(lambda x: clean_and_validate_district(target_state, x['district']), axis=1)
    state_df = state_df.dropna(subset=['district_clean'])

    # Feature Engineering: Total Count
    # Summing up detected bio columns
    state_df['total_count'] = state_df[bio_cols].sum(axis=1)

    # Dates
    state_df['date'] = pd.to_datetime(state_df['date'], errors='coerce')
    state_df['month'] = state_df['date'].dt.strftime('%m')

    # SAVE 1: District Summary
    dist_sum = state_df.groupby('district_clean')[bio_cols + ['total_count']].sum().reset_index()
    dist_sum.to_csv(f"{output_folder}{target_state}_District_Summary.csv", index=False)

    # SAVE 2: Monthly Trend
    month_sum = state_df.groupby('month')[bio_cols + ['total_count']].sum().reset_index()
    month_sum.to_csv(f"{output_folder}{target_state}_Monthly_Trend.csv", index=False)

    # SAVE 3: Detailed Cleaned File
    # Remove temporary columns
    final_state_df = state_df.drop(columns=['district', 'state'], errors='ignore')
    final_state_df.to_csv(f"{output_folder}{target_state}_Detailed_Cleaned.csv", index=False)

    return final_state_df

# --- EXECUTION ---
all_states = df_bio['state_clean'].unique()
cleaned_data_list = []

print(f"Starting batch processing for {len(all_states)} states...")

for state in all_states:
    if state in official_districts:
        res = process_biometric_state(state)
        if res is not None:
            cleaned_data_list.append(res)

# Save Master File
if cleaned_data_list:
    master_df = pd.concat(cleaned_data_list, ignore_index=True)
    master_df.to_csv('/content/drive/MyDrive/UIDAI Hackathon 2026/Master_Cleaned_Biometric_All_States.csv', index=False)
    print("\n✅ SUCCESS! All Biometric files saved.")

    # --- FINAL REPORT ---
    print("\n--- CLEANED BIOMETRIC DISTRICTS REPORT ---")
    for state in sorted(master_df['state_clean'].unique()):
        dists = sorted(master_df[master_df['state_clean'] == state]['district_clean'].unique())
        print(f"📍 {state.upper()} ({len(dists)}): {', '.join(dists)}")
        print("-" * 50)
# Out:
# Loading Biometric Data...
# Loaded 1861108 rows.
# Detected Biometric Columns: ['bio_age_5_17', 'bio_age_17_']
# Starting batch processing for 48 states...
# Processing: Goa...
# Processing: Gujarat...
# /tmp/ipython-input-730293463.py:165: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   state_df['date'] = pd.to_datetime(state_df['date'], errors='coerce')
# /tmp/ipython-input-730293463.py:165: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   state_df['date'] = pd.to_datetime(state_df['date'], errors='coerce')
# Processing: Haryana...
# /tmp/ipython-input-730293463.py:165: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
# ...

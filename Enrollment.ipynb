# %% [markdown]
# # At start EDA only done on 1 State after that on all States

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importing enrollment 1 file

# %%
enroll_1 = pd.read_csv("/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_enrolment/api_data_aadhar_enrolment_0_500000.csv")
enroll_1.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
enroll_1.shape
# Out:
# (500000, 7)

# %%
enroll_1['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
#        'andhra pradesh', 'ODISHA'], dtype=object)

# %%
enroll_1['new_date']=pd.to_datetime(enroll_1['date'], format='%d-%m-%Y').dt.strftime('%Y%m%d')
enroll_1
# Out:
#               date           state          district  pincode  age_0_5  \
# 0       02-03-2025       Meghalaya  East Khasi Hills   793121       11
# 1       09-03-2025       Karnataka   Bengaluru Urban   560043       14
# 2       09-03-2025   Uttar Pradesh      Kanpur Nagar   208001       29
# 3       09-03-2025   Uttar Pradesh           Aligarh   202133       62
# 4       09-03-2025       Karnataka   Bengaluru Urban   560016       14
# ...            ...             ...               ...      ...      ...
# 499995  26-10-2025  Andhra Pradesh       Mahbubnagar   509207        1
# 499996  26-10-2025  Andhra Pradesh             Medak   502220        1
# 499997  26-10-2025  Andhra Pradesh             Medak   502256        0
# 499998  26-10-2025  Andhra Pradesh             Medak   502286        1
# 499999  26-10-2025  Andhra Pradesh           N. T. R   521402        1
#
#         age_5_17  age_18_greater  new_date
# 0             61              37  20250302
# 1             33              39  20250309
# 2             82              12  20250309
# 3             29              15  20250309
# 4             16              21  20250309
# ...          ...             ...       ...
# 499995         0               0  20251026
# 499996         0               0  20251026
# 499997         1               0  20251026
# 499998         0               0  20251026
# 499999         0               0  20251026
#
# [500000 rows x 8 columns]

# %%
enroll_1['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(enroll_1['new_date'].max())
print(enroll_1['new_date'].min())
# Out:
# 20251026
# 20250302

# %% [markdown]
# ### Importing Enrollment-2 File

# %%
enroll_2=pd.read_csv("/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_enrolment/api_data_aadhar_enrolment_500000_1000000.csv")
enroll_2.head()
# Out:
#          date           state  district  pincode  age_0_5  age_5_17  \
# 0  26-10-2025  Andhra Pradesh  Nalgonda   508004        0         1
# 1  26-10-2025  Andhra Pradesh  Nalgonda   508238        1         0
# 2  26-10-2025  Andhra Pradesh  Nalgonda   508278        1         0
# 3  26-10-2025  Andhra Pradesh   Nandyal   518432        0         1
# 4  26-10-2025  Andhra Pradesh   Nandyal   518543        1         0
#
#    age_18_greater
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
enroll_2.shape
# Out:
# (500000, 7)

# %%
enroll_2['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'West Bengal',
#        'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Bihar', 'Chandigarh', 'Sikkim', 'West Bangal',
#        'Dadra and Nagar Haveli', 'Daman and Diu',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Jammu & Kashmir',
#        'andhra pradesh', 'Dadra & Nagar Haveli', 'Westbengal',
#        'Daman & Diu', 'WESTBENGAL', 'West bengal', 'West  Bengal',
#        'WEST BENGAL', '100000'], dtype=object)

# %%
enroll_2['new_date']=pd.to_datetime(enroll_2['date']).dt.strftime('%Y%m%d')
enroll_2
# Out:
# /tmp/ipython-input-1392542173.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   enroll_2['new_date']=pd.to_datetime(enroll_2['date']).dt.strftime('%Y%m%d')
#               date           state   district  pincode  age_0_5  age_5_17  \
# 0       26-10-2025  Andhra Pradesh   Nalgonda   508004        0         1
# 1       26-10-2025  Andhra Pradesh   Nalgonda   508238        1         0
# 2       26-10-2025  Andhra Pradesh   Nalgonda   508278        1         0
# 3       26-10-2025  Andhra Pradesh    Nandyal   518432        0         1
# 4       26-10-2025  Andhra Pradesh    Nandyal   518543        1         0
# ...            ...             ...        ...      ...      ...       ...
# 499995  31-12-2025       Telangana  Hyderabad   500045        4         5
# 499996  31-12-2025       Telangana  Hyderabad   500057        0         2
# 499997  31-12-2025       Telangana  Hyderabad   500061        4         2
# 499998  31-12-2025       Telangana  Hyderabad   500062        1         4
# 499999  31-12-2025       Telangana  Hyderabad   500095        0         1
#
#         age_18_greater  new_date
# 0                    0  20251026
# 1                    0  20251026
# 2                    0  20251026
# 3                    0  20251026
# 4                    0  20251026
# ...                ...       ...
# 499995               1  20251231
# 499996               0  20251231
# 499997               0  20251231
# 499998               0  20251231
# 499999               0  20251231
#
# [500000 rows x 8 columns]

# %%
enroll_2['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(enroll_2['new_date'].max())
print(enroll_2['new_date'].min())
# Out:
# 20251231
# 20251026

# %% [markdown]
# ### Importing Enrollment-3 file

# %%
enroll_3=pd.read_csv("/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_enrolment/api_data_aadhar_enrolment_1000000_1006029.csv")
enroll_3.head()
# Out:
#          date      state district  pincode  age_0_5  age_5_17  age_18_greater
# 0  31-12-2025  Karnataka    Bidar   585330        2         3               0
# 1  31-12-2025  Karnataka    Bidar   585402        6         0               0
# 2  31-12-2025  Karnataka    Bidar   585413        1         0               0
# 3  31-12-2025  Karnataka    Bidar   585418        1         2               0
# 4  31-12-2025  Karnataka    Bidar   585421        4         3               0

# %%
enroll_3.shape
# Out:
# (6029, 7)

# %%
enroll_3['state'].unique()
# Out:
# array(['Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Orissa', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Daman and Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Pondicherry'], dtype=object)

# %%
enroll_3['new_date']=pd.to_datetime(enroll_3['date']).dt.strftime('%Y%m%d')
enroll_3
# Out:
# /tmp/ipython-input-1907064582.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   enroll_3['new_date']=pd.to_datetime(enroll_3['date']).dt.strftime('%Y%m%d')
#             date        state        district  pincode  age_0_5  age_5_17  \
# 0     31-12-2025    Karnataka           Bidar   585330        2         3
# 1     31-12-2025    Karnataka           Bidar   585402        6         0
# 2     31-12-2025    Karnataka           Bidar   585413        1         0
# 3     31-12-2025    Karnataka           Bidar   585418        1         2
# 4     31-12-2025    Karnataka           Bidar   585421        4         3
# ...          ...          ...             ...      ...      ...       ...
# 6024  31-12-2025  West Bengal  West Midnapore   721149        2         0
# 6025  31-12-2025  West Bengal  West Midnapore   721150        2         2
# 6026  31-12-2025  West Bengal  West Midnapore   721305        0         1
# 6027  31-12-2025  West Bengal  West Midnapore   721504        1         0
# 6028  31-12-2025  West Bengal  West Midnapore   721517        2         1
#
#       age_18_greater  new_date
# 0                  0  20251231
# 1                  0  20251231
# 2                  0  20251231
# 3                  0  20251231
# 4                  0  20251231
# ...              ...       ...
# 6024               0  20251231
# 6025               0  20251231
# 6026               0  20251231
# 6027               0  20251231
# 6028               0  20251231
#
# [6029 rows x 8 columns]

# %%
enroll_3['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(enroll_3['new_date'].max())
print(enroll_3['new_date'].min())
# Out:
# 20251231
# 20251231

# %%
### Merging three dataset

# %%
df = pd.concat([enroll_1, enroll_2, enroll_3], axis=0, ignore_index=True)
df.shape
# Out:
# (1006029, 8)

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater  new_date
# 0              37  20250302
# 1              39  20250309
# 2              12  20250309
# 3              15  20250309
# 4              21  20250309

# %%
df['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
# unique count of state
df['state'].nunique()
# Out:
# 55

# %%
df['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu',
#        'Arunachal Pradesh', 'Himachal Pradesh', 'Goa',
#        'Jammu And Kashmir', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Lakshadweep', 'Andaman & Nicobar Islands',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman and Diu',
#        'WEST BENGAL', 'Jammu & Kashmir', 'West  Bengal', '100000',
#        'Daman & Diu', 'West Bangal', 'Westbengal', 'West bengal',
#        'andhra pradesh', 'ODISHA', 'WESTBENGAL'], dtype=object)

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove symbols like &, .
    x = re.sub(r'\s+', ' ', x).strip()  # remove extra spaces
    return x

# %%
state_mapping = {
    # West Bengal
    'west bengal': 'West Bengal',
    'west bangal': 'West Bengal',
    'westbengal': 'West Bengal',
    'west  bengal': 'West Bengal',
    'westbengal ': 'West Bengal',

    # Andhra Pradesh
    'andhra pradesh': 'Andhra Pradesh',

    # Odisha
    'odisha': 'Odisha',
    'orissa': 'Odisha',

    # Jammu & Kashmir
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',

    # Collapse all Dadra / Daman variants into ONE state
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'the dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',


    # Puducherry
    'puducherry': 'Puducherry',


    # Andaman & Nicobar Islands
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Puducherry
    'pondicherry': 'Puducherry',

    # Case-normalized direct matches
    'delhi': 'Delhi',
    'ladakh': 'Ladakh',
    'goa': 'Goa',
    'sikkim': 'Sikkim',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'punjab': 'Punjab',
    'kerala': 'Kerala',
    'haryana': 'Haryana',
    'gujarat': 'Gujarat',
    'tamil nadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'karnataka': 'Karnataka',
    'maharashtra': 'Maharashtra',
    'rajasthan': 'Rajasthan',
    'uttar pradesh': 'Uttar Pradesh',
    'madhya pradesh': 'Madhya Pradesh',
    'himachal pradesh': 'Himachal Pradesh',
    'arunachal pradesh': 'Arunachal Pradesh',
    'chhattisgarh': 'Chhattisgarh',
    'jharkhand': 'Jharkhand',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'tripura': 'Tripura',
    'uttarakhand': 'Uttarakhand',
    'lakshadweep': 'Lakshadweep',
    'chandigarh': 'Chandigarh'
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries like numeric junk
df = df[~df['state'].astype(str).str.isnumeric()]

# Optional: check unmapped states
unmapped = df[df['state_clean'].isna()]['state'].unique()
print("Unmapped values:", unmapped)
# Out:
# Unmapped values: []

# %%
df['state_clean'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Arunachal Pradesh',
#        'Himachal Pradesh', 'Goa', 'Ladakh', 'Andaman and Nicobar Islands',
#        'Puducherry', 'Lakshadweep'], dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
df
# Out:
#                date          state          district  pincode  age_0_5  \
# 0        02-03-2025      Meghalaya  East Khasi Hills   793121       11
# 1        09-03-2025      Karnataka   Bengaluru Urban   560043       14
# 2        09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29
# 3        09-03-2025  Uttar Pradesh           Aligarh   202133       62
# 4        09-03-2025      Karnataka   Bengaluru Urban   560016       14
# ...             ...            ...               ...      ...      ...
# 1006024  31-12-2025    West Bengal    West Midnapore   721149        2
# 1006025  31-12-2025    West Bengal    West Midnapore   721150        2
# 1006026  31-12-2025    West Bengal    West Midnapore   721305        0
# 1006027  31-12-2025    West Bengal    West Midnapore   721504        1
# 1006028  31-12-2025    West Bengal    West Midnapore   721517        2
#
#          age_5_17  age_18_greater  new_date    state_clean
# 0              61              37  20250302      Meghalaya
# 1              33              39  20250309      Karnataka
# 2              82              12  20250309  Uttar Pradesh
# 3              29              15  20250309  Uttar Pradesh
# 4              16              21  20250309      Karnataka
# ...           ...             ...       ...            ...
# 1006024         0               0  20251231    West Bengal
# 1006025         2               0  20251231    West Bengal
# 1006026         1               0  20251231    West Bengal
# 1006027         0               0  20251231    West Bengal
# 1006028         1               0  20251231    West Bengal
#
# [1006007 rows x 9 columns]

# %%
df.dtypes
# Out:
# date              object
# state             object
# district          object
# pincode            int64
# age_0_5            int64
# age_5_17           int64
# age_18_greater     int64
# new_date          object
# state_clean       object
# dtype: object

# %%
df_bihar=df[df['state_clean']=='Bihar']
df_bihar
# Out:
#                date  state         district  pincode  age_0_5  age_5_17  \
# 5        09-03-2025  Bihar        Sitamarhi   843331       20        49
# 6        09-03-2025  Bihar        Sitamarhi   843330       23        24
# 9        09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 11       09-03-2025  Bihar        Sitamarhi   843317       35        94
# 13       09-03-2025  Bihar        Sitamarhi   843324       49       186
# ...             ...    ...              ...      ...      ...       ...
# 1002992  31-12-2025  Bihar         Vaishali   844134        2         0
# 1002993  31-12-2025  Bihar         Vaishali   844504       15        26
# 1002994  31-12-2025  Bihar         Vaishali   844509        1         2
# 1002995  31-12-2025  Bihar   West Champaran   845404       13        17
# 1002996  31-12-2025  Bihar   West Champaran   845449        9        45
#
#          age_18_greater  new_date state_clean
# 5                    12  20250309       Bihar
# 6                    42  20250309       Bihar
# 9                    10  20250309       Bihar
# 11                   16  20250309       Bihar
# 13                   34  20250309       Bihar
# ...                 ...       ...         ...
# 1002992               0  20251231       Bihar
# 1002993               1  20251231       Bihar
# 1002994               0  20251231       Bihar
# 1002995               1  20251231       Bihar
# 1002996               0  20251231       Bihar
#
# [60567 rows x 9 columns]

# %%
df_bihar['district'].unique()
# Out:
# array(['Sitamarhi', 'Purbi Champaran', 'Madhubani', 'Bhagalpur', 'Patna',
#        'Pashchim Champaran', 'Muzaffarpur', 'Munger', 'Gaya',
#        'Kaimur (Bhabua)', 'West Champaran', 'Purnia', 'Saran',
#        'East Champaran', 'Vaishali', 'Jehanabad', 'Jamui', 'Gopalganj',
#        'Saharsa', 'Arwal', 'Katihar', 'Siwan', 'Lakhisarai', 'Banka',
#        'Nalanda', 'Araria', 'Darbhanga', 'Nawada', 'Samastipur',
#        'Begusarai', 'Bhojpur', 'Aurangabad', 'Buxar', 'Khagaria',
#        'Kishanganj', 'Madhepura', 'Rohtas', 'Sheohar', 'Supaul',
#        'Aurangabad(bh)', 'Purba Champaran', 'Purnea', 'Sheikhpura',
#        'Sheikpura', 'Bhabua', 'Monghyr', 'Samstipur', 'Aurangabad(BH)'],
#       dtype=object)

# %%
import re
import pandas as pd

def clean_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove (), ., etc
    x = re.sub(r'\s+', ' ', x).strip()
    return x

# %%
district_mapping_bihar = {

    # Champaran
    'purbi champaran': 'East Champaran',
    'purba champaran': 'East Champaran',
    'east champaran': 'East Champaran',

    'pashchim champaran': 'West Champaran',
    'west champaran': 'West Champaran',

    # Aurangabad
    'aurangabad bh': 'Aurangabad',
    'aurangabad bh ': 'Aurangabad',
    'aurangabad': 'Aurangabad',

    # Purnia
    'purnia': 'Purnia',
    'purnea': 'Purnia',

    # Kaimur
    'kaimur bhabua': 'Kaimur',
    'bhabua': 'Kaimur',

    # Munger
    'munger': 'Munger',
    'monghyr': 'Munger',

    # Samastipur
    'samastipur': 'Samastipur',
    'samstipur': 'Samastipur',

    # Sheikhpura
    'sheikhpura': 'Sheikhpura',
    'sheikpura': 'Sheikhpura',

    # Normalized direct matches
    'sitamarhi': 'Sitamarhi',
    'madhubani': 'Madhubani',
    'bhagalpur': 'Bhagalpur',
    'patna': 'Patna',
    'muzaffarpur': 'Muzaffarpur',
    'gaya': 'Gaya',
    'saran': 'Saran',
    'vaishali': 'Vaishali',
    'jehanabad': 'Jehanabad',
    'jamui': 'Jamui',
    'gopalganj': 'Gopalganj',
    'saharsa': 'Saharsa',
    'arwal': 'Arwal',
    'katihar': 'Katihar',
    'siwan': 'Siwan',
    'lakhisarai': 'Lakhisarai',
    'banka': 'Banka',
    'nalanda': 'Nalanda',
    'araria': 'Araria',
    'darbhanga': 'Darbhanga',
    'nawada': 'Nawada',
    'begusarai': 'Begusarai',
    'bhojpur': 'Bhojpur',
    'buxar': 'Buxar',
    'khagaria': 'Khagaria',
    'kishanganj': 'Kishanganj',
    'madhepura': 'Madhepura',
    'rohtas': 'Rohtas',
    'sheohar': 'Sheohar',
    'supaul': 'Supaul'
}

# %%
df_bihar['district_clean'] = (
    df_bihar['district']
    .apply(clean_name)
    .map(district_mapping_bihar)
    .fillna(df_bihar['district'])
)
# Out:
# /tmp/ipython-input-828442334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['district_clean'] = (

# %%
# Remaining unmapped
df_bihar[df_bihar['district_clean'].isna()]['district'].unique()

# Count check
df_bihar['district_clean'].nunique()
# Out:
# 38

# %%
df_bihar
# Out:
#                date  state         district  pincode  age_0_5  age_5_17  \
# 5        09-03-2025  Bihar        Sitamarhi   843331       20        49
# 6        09-03-2025  Bihar        Sitamarhi   843330       23        24
# 9        09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 11       09-03-2025  Bihar        Sitamarhi   843317       35        94
# 13       09-03-2025  Bihar        Sitamarhi   843324       49       186
# ...             ...    ...              ...      ...      ...       ...
# 1002992  31-12-2025  Bihar         Vaishali   844134        2         0
# 1002993  31-12-2025  Bihar         Vaishali   844504       15        26
# 1002994  31-12-2025  Bihar         Vaishali   844509        1         2
# 1002995  31-12-2025  Bihar   West Champaran   845404       13        17
# 1002996  31-12-2025  Bihar   West Champaran   845449        9        45
#
#          age_18_greater  new_date state_clean  district_clean
# 5                    12  20250309       Bihar       Sitamarhi
# 6                    42  20250309       Bihar       Sitamarhi
# 9                    10  20250309       Bihar  East Champaran
# 11                   16  20250309       Bihar       Sitamarhi
# 13                   34  20250309       Bihar       Sitamarhi
# ...                 ...       ...         ...             ...
# 1002992               0  20251231       Bihar        Vaishali
# 1002993               1  20251231       Bihar        Vaishali
# 1002994               0  20251231       Bihar        Vaishali
# 1002995               1  20251231       Bihar  West Champaran
# 1002996               0  20251231       Bihar  West Champaran
#
# [60567 rows x 10 columns]

# %%
df_bihar['district_clean'].unique()
# Out:
# array(['Sitamarhi', 'East Champaran', 'Madhubani', 'Bhagalpur', 'Patna',
#        'West Champaran', 'Muzaffarpur', 'Munger', 'Gaya', 'Kaimur',
#        'Purnia', 'Saran', 'Vaishali', 'Jehanabad', 'Jamui', 'Gopalganj',
#        'Saharsa', 'Arwal', 'Katihar', 'Siwan', 'Lakhisarai', 'Banka',
#        'Nalanda', 'Araria', 'Darbhanga', 'Nawada', 'Samastipur',
#        'Begusarai', 'Bhojpur', 'Aurangabad', 'Buxar', 'Khagaria',
#        'Kishanganj', 'Madhepura', 'Rohtas', 'Sheohar', 'Supaul',
#        'Sheikhpura'], dtype=object)

# %%
df_bihar['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
# unique count pincode
df_bihar['pincode'].nunique()
# Out:
# 906

# %%
# df_bihar[['district_clean','pincode']].value_counts().reset_index(name='count')

# %%
pincode_check=df_bihar.groupby('district_clean')['pincode'].nunique().reset_index(name='unique_pincode_count')

# %%
pincode_check
# Out:
#     district_clean  unique_pincode_count
# 0           Araria                    19
# 1            Arwal                    19
# 2       Aurangabad                    29
# 3            Banka                    32
# 4        Begusarai                    33
# 5        Bhagalpur                    34
# 6          Bhojpur                    41
# 7            Buxar                    27
# 8        Darbhanga                    46
# 9   East Champaran                    39
# 10            Gaya                    39
# 11       Gopalganj                    23
# 12           Jamui                    14
# 13       Jehanabad                    21
# 14          Kaimur                    12
# 15         Katihar                    23
# 16        Khagaria                    15
# 17      Kishanganj                     9
# 18      Lakhisarai                    13
# 19       Madhepura                    21
# 20       Madhubani                    44
# 21          Munger                    12
# 22     Muzaffarpur                    53
# 23         Nalanda                    31
# 24          Nawada                    24
# 25           Patna                    69
# 26          Purnia                    30
# 27          Rohtas                    33
# 28         Saharsa                    18
# 29      Samastipur                    42
# 30           Saran                    51
# 31      Sheikhpura                     8
# 32         Sheohar                     7
# 33       Sitamarhi                    25
# 34           Siwan                    46
# 35          Supaul                    23
# 36        Vaishali                    38
# 37  West Champaran                    19

# %%
df_bihar[df_bihar['district_clean']=='Vaishali']['pincode'].unique()
# Out:
# array([844504, 844112, 844114, 844115, 844118, 844119, 844120, 844121,
#        844125, 844126, 844503, 844123, 844506, 844507, 843102, 843110,
#        844122, 844124, 844501, 844505, 844509, 843114, 844113, 844117,
#        844101, 844102, 844111, 844116, 844128, 844131, 844134, 844502,
#        844508, 843104, 844141, 844139, 843105, 844103])

# %%
pin_district_count = (
    df_bihar.groupby('pincode')['district_clean']
      .nunique()
      .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#      pincode  district_count
# 0     800001               1
# 1     800002               1
# 2     800003               1
# 3     800004               1
# 4     800005               1
# ..       ...             ...
# 901   855114               1
# 902   855115               2
# 903   855116               1
# 904   855117               1
# 905   855456               1
#
# [906 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
# Out:
#      pincode  district_count
# 40    801304               2
# 41    801305               2
# 53    802112               2
# 73    802134               2
# 83    802160               2
# ..       ...             ...
# 890   854337               2
# 894   855101               3
# 896   855105               2
# 898   855107               2
# 902   855115               2
#
# [165 rows x 2 columns]

# %%
df_flagged = df_bihar.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
df_flagged
# Out:
#              date  state   district  pincode  age_0_5  age_5_17  \
# 0      01-04-2025  Bihar  Sitamarhi   843315      102       125
# 1      01-04-2025  Bihar     Munger   811213      191       278
# 2      01-04-2025  Bihar  Bhagalpur   853204      349       238
# 3      01-04-2025  Bihar     Purnia   854304      517       276
# 4      01-04-2025  Bihar       Gaya   824233       63       317
# ...           ...    ...        ...      ...      ...       ...
# 16010  31-12-2025  Bihar    Sheohar   843325        4         2
# 16011  31-12-2025  Bihar  Sitamarhi   843325       11         6
# 16012  31-12-2025  Bihar      Siwan   841243        2        11
# 16013  31-12-2025  Bihar     Supaul   852108        0         9
# 16014  31-12-2025  Bihar     Supaul   852131       15        19
#
#        age_18_greater  new_date state_clean district_clean
# 0                  18  20250401       Bihar      Sitamarhi
# 1                  22  20250401       Bihar         Munger
# 2                  10  20250401       Bihar      Bhagalpur
# 3                  21  20250401       Bihar         Purnia
# 4                  13  20250401       Bihar           Gaya
# ...               ...       ...         ...            ...
# 16010               0  20251231       Bihar        Sheohar
# 16011               0  20251231       Bihar      Sitamarhi
# 16012               0  20251231       Bihar          Siwan
# 16013               0  20251231       Bihar         Supaul
# 16014               0  20251231       Bihar         Supaul
#
# [16015 rows x 10 columns]

# %%
flagged_pincode_dominant=df_flagged.groupby(['district_clean', 'pincode'])[['age_0_5','age_5_17','age_18_greater']].sum().reset_index()
# flagged_pincode_dominant.to_excel('flagged_pincode_dominan.xlsx')

# %%
flagged_pincode_dominant['total_enroll']=flagged_pincode_dominant['age_0_5']+flagged_pincode_dominant['age_5_17']+flagged_pincode_dominant['age_18_greater']
flagged_pincode_dominant.sort_values('pincode')
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  total_enroll
# 229          Patna   801304       17        36               1            54
# 211        Nalanda   801304       58       114               0           172
# 230          Patna   801305       12        33               2            47
# 212        Nalanda   801305       39        62               1           102
# 57         Bhojpur   802112       48       131               0           179
# ..             ...      ...      ...       ...             ...           ...
# 146        Katihar   855105      386       125               6           517
# 154     Kishanganj   855107     1685       446               1          2132
# 259         Purnia   855107      235        70               0           305
# 260         Purnia   855115      222        60               0           282
# 155     Kishanganj   855115      774       208               4           986
#
# [341 rows x 6 columns]

# %%
idx = flagged_pincode_dominant.groupby('pincode')['total_enroll'].idxmax()
df_filtered = flagged_pincode_dominant.loc[idx]
df_filtered
# Out:
#     district_clean  pincode  age_0_5  age_5_17  age_18_greater  total_enroll
# 211        Nalanda   801304       58       114               0           172
# 212        Nalanda   801305       39        62               1           102
# 63           Buxar   802112      117       224               1           342
# 64           Buxar   802134      125       370               1           496
# 59         Bhojpur   802160       66       273               2           341
# ..             ...      ...      ...       ...             ...           ...
# 257         Purnia   854337      336       131               0           467
# 153     Kishanganj   855101     1906       357               7          2270
# 146        Katihar   855105      386       125               6           517
# 154     Kishanganj   855107     1685       446               1          2132
# 155     Kishanganj   855115      774       208               4           986
#
# [165 rows x 6 columns]

# %%
df_bihar['pin_multi_district_flag'] = (
    df_bihar.groupby('pincode')['district']
      .transform('nunique') > 1
)
# Out:
# /tmp/ipython-input-3362433199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['pin_multi_district_flag'] = (

# %%
pin_district_map = (
    df_bihar[df_bihar['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']
    .unique()
    .reset_index()
)

# %%
file_path='pin_district_map.xlsx'
pin_district_map.to_excel(file_path, index=False)

# %%
df_bihar['pin_multi_district_flag'].value_counts()
# Out:
# pin_multi_district_flag
# False    37147
# True     23420
# Name: count, dtype: int64

# %%
df_bihar['total_enroll']=df_bihar['age_0_5']+df_bihar['age_5_17']+df_bihar['age_18_greater']
df_bihar
# Out:
# /tmp/ipython-input-2455090128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['total_enroll']=df_bihar['age_0_5']+df_bihar['age_5_17']+df_bihar['age_18_greater']
#                date  state         district  pincode  age_0_5  age_5_17  \
# 5        09-03-2025  Bihar        Sitamarhi   843331       20        49
# 6        09-03-2025  Bihar        Sitamarhi   843330       23        24
# 9        09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 11       09-03-2025  Bihar        Sitamarhi   843317       35        94
# 13       09-03-2025  Bihar        Sitamarhi   843324       49       186
# ...             ...    ...              ...      ...      ...       ...
# 1002992  31-12-2025  Bihar         Vaishali   844134        2         0
# 1002993  31-12-2025  Bihar         Vaishali   844504       15        26
# 1002994  31-12-2025  Bihar         Vaishali   844509        1         2
# 1002995  31-12-2025  Bihar   West Champaran   845404       13        17
# 1002996  31-12-2025  Bihar   West Champaran   845449        9        45
#
#          age_18_greater  new_date state_clean  district_clean  \
# 5                    12  20250309       Bihar       Sitamarhi
# 6                    42  20250309       Bihar       Sitamarhi
# 9                    10  20250309       Bihar  East Champaran
# 11                   16  20250309       Bihar       Sitamarhi
# 13                   34  20250309       Bihar       Sitamarhi
# ...                 ...       ...         ...             ...
# 1002992               0  20251231       Bihar        Vaishali
# 1002993               1  20251231       Bihar        Vaishali
# 1002994               0  20251231       Bihar        Vaishali
# 1002995               1  20251231       Bihar  West Champaran
# 1002996               0  20251231       Bihar  West Champaran
#
#          pin_multi_district_flag  total_enroll
# 5                          False            81
# 6                          False            89
# 9                           True            88
# 11                         False           145
# 13                         False           269
# ...                          ...           ...
# 1002992                    False             2
# 1002993                    False            42
# 1002994                    False             3
# 1002995                    False            31
# 1002996                     True            54
#
# [60567 rows x 12 columns]

# %%
df_bihar['month']=df_bihar['new_date'].astype(str).str[4:6]
df_bihar
# Out:
# /tmp/ipython-input-3723542462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bihar['month']=df_bihar['new_date'].astype(str).str[4:6]
#                date  state         district  pincode  age_0_5  age_5_17  \
# 5        09-03-2025  Bihar        Sitamarhi   843331       20        49
# 6        09-03-2025  Bihar        Sitamarhi   843330       23        24
# 9        09-03-2025  Bihar  Purbi Champaran   845418       30        48
# 11       09-03-2025  Bihar        Sitamarhi   843317       35        94
# 13       09-03-2025  Bihar        Sitamarhi   843324       49       186
# ...             ...    ...              ...      ...      ...       ...
# 1002992  31-12-2025  Bihar         Vaishali   844134        2         0
# 1002993  31-12-2025  Bihar         Vaishali   844504       15        26
# 1002994  31-12-2025  Bihar         Vaishali   844509        1         2
# 1002995  31-12-2025  Bihar   West Champaran   845404       13        17
# 1002996  31-12-2025  Bihar   West Champaran   845449        9        45
#
#          age_18_greater  new_date state_clean  district_clean  \
# 5                    12  20250309       Bihar       Sitamarhi
# 6                    42  20250309       Bihar       Sitamarhi
# 9                    10  20250309       Bihar  East Champaran
# 11                   16  20250309       Bihar       Sitamarhi
# 13                   34  20250309       Bihar       Sitamarhi
# ...                 ...       ...         ...             ...
# 1002992               0  20251231       Bihar        Vaishali
# 1002993               1  20251231       Bihar        Vaishali
# 1002994               0  20251231       Bihar        Vaishali
# 1002995               1  20251231       Bihar  West Champaran
# 1002996               0  20251231       Bihar  West Champaran
#
#          pin_multi_district_flag  total_enroll month
# 5                          False            81    03
# 6                          False            89    03
# 9                           True            88    03
# 11                         False           145    03
# 13                         False           269    03
# ...                          ...           ...   ...
# 1002992                    False             2    12
# 1002993                    False            42    12
# 1002994                    False             3    12
# 1002995                    False            31    12
# 1002996                     True            54    12
#
# [60567 rows x 13 columns]

# %%
df_bihar_cleaned=df_bihar.drop(columns=['date','district','state'], axis=1)
df_bihar_cleaned
# Out:
#          pincode  age_0_5  age_5_17  age_18_greater  new_date state_clean  \
# 5         843331       20        49              12  20250309       Bihar
# 6         843330       23        24              42  20250309       Bihar
# 9         845418       30        48              10  20250309       Bihar
# 11        843317       35        94              16  20250309       Bihar
# 13        843324       49       186              34  20250309       Bihar
# ...          ...      ...       ...             ...       ...         ...
# 1002992   844134        2         0               0  20251231       Bihar
# 1002993   844504       15        26               1  20251231       Bihar
# 1002994   844509        1         2               0  20251231       Bihar
# 1002995   845404       13        17               1  20251231       Bihar
# 1002996   845449        9        45               0  20251231       Bihar
#
#          district_clean  pin_multi_district_flag  total_enroll month
# 5             Sitamarhi                    False            81    03
# 6             Sitamarhi                    False            89    03
# 9        East Champaran                     True            88    03
# 11            Sitamarhi                    False           145    03
# 13            Sitamarhi                    False           269    03
# ...                 ...                      ...           ...   ...
# 1002992        Vaishali                    False             2    12
# 1002993        Vaishali                    False            42    12
# 1002994        Vaishali                    False             3    12
# 1002995  West Champaran                    False            31    12
# 1002996  West Champaran                     True            54    12
#
# [60567 rows x 10 columns]

# %%
df_bihar_dist_level=df_bihar_cleaned.groupby('district_clean')[['age_0_5','age_5_17','age_18_greater','total_enroll']].sum()
df_bihar_dist_level.shape
# Out:
# (38, 4)

# %%
df_bihar_dist_level
# Out:
#                 age_0_5  age_5_17  age_18_greater  total_enroll
# district_clean
# Araria             9939      5515             125         15579
# Arwal               812      3020              34          3866
# Aurangabad         3050      7160              73         10283
# Banka              6198      4797              79         11074
# Begusarai          8106      5045              58         13209
# Bhagalpur         10456     10229             377         21062
# Bhojpur            3136     10115             106         13357
# Buxar              2528      4648              64          7240
# Darbhanga         10017      5677              71         15765
# East Champaran    14208     28508            1605         44321
# Gaya               6722     20244             435         27401
# Gopalganj          5303      9649             196         15148
# Jamui              5193      5029             160         10382
# Jehanabad           915      3827             141          4883
# Kaimur             3047      4724              85          7856
# Katihar           11332      4903             115         16350
# Khagaria           4348      3779              69          8196
# Kishanganj         6957      1782              25          8764
# Lakhisarai         2664      3423              68          6155
# Madhepura          4571      4417              39          9027
# Madhubani         12598     12534             798         25930
# Munger             2474      3554             108          6136
# Muzaffarpur       14087     14103             665         28855
# Nalanda            3676     10763             136         14575
# Nawada             2742     12380             291         15413
# Patna              6745     17151             748         24644
# Purnia            12364      7809             184         20357
# Rohtas             2741      5120              78          7939
# Saharsa            6281      6577             205         13063
# Samastipur        11330      7828             131         19289
# Saran              7592     16407             219         24218
# Sheikhpura         1255      1952              21          3228
# Sheohar            2067      1184              11          3262
# Sitamarhi         20679     18856            2697         42232
# Siwan              6149      9025             137         15311
# Supaul             5691      4563             157         10411
# Vaishali           8257      9698              52         18007
# West Champaran    16645     28807            1345         46797

# %%
df_bihar_dist_level.sort_values('total_enroll', ascending=False).reset_index()
# df_bihar_dist_level.to_excel("df_bihar_dist_level.xlsx")
# Out:
#     district_clean  age_0_5  age_5_17  age_18_greater  total_enroll
# 0   West Champaran    16645     28807            1345         46797
# 1   East Champaran    14208     28508            1605         44321
# 2        Sitamarhi    20679     18856            2697         42232
# 3      Muzaffarpur    14087     14103             665         28855
# 4             Gaya     6722     20244             435         27401
# 5        Madhubani    12598     12534             798         25930
# 6            Patna     6745     17151             748         24644
# 7            Saran     7592     16407             219         24218
# 8        Bhagalpur    10456     10229             377         21062
# 9           Purnia    12364      7809             184         20357
# 10      Samastipur    11330      7828             131         19289
# 11        Vaishali     8257      9698              52         18007
# 12         Katihar    11332      4903             115         16350
# 13       Darbhanga    10017      5677              71         15765
# 14          Araria     9939      5515             125         15579
# 15          Nawada     2742     12380             291         15413
# 16           Siwan     6149      9025             137         15311
# 17       Gopalganj     5303      9649             196         15148
# 18         Nalanda     3676     10763             136         14575
# 19         Bhojpur     3136     10115             106         13357
# 20       Begusarai     8106      5045              58         13209
# 21         Saharsa     6281      6577             205         13063
# 22           Banka     6198      4797              79         11074
# 23          Supaul     5691      4563             157         10411
# 24           Jamui     5193      5029             160         10382
# 25      Aurangabad     3050      7160              73         10283
# 26       Madhepura     4571      4417              39          9027
# 27      Kishanganj     6957      1782              25          8764
# 28        Khagaria     4348      3779              69          8196
# 29          Rohtas     2741      5120              78          7939
# 30          Kaimur     3047      4724              85          7856
# 31           Buxar     2528      4648              64          7240
# 32      Lakhisarai     2664      3423              68          6155
# 33          Munger     2474      3554             108          6136
# 34       Jehanabad      915      3827             141          4883
# 35           Arwal      812      3020              34          3866
# 36         Sheohar     2067      1184              11          3262
# 37      Sheikhpura     1255      1952              21          3228

# %%
df_bihar_dist_level1=df_bihar_dist_level.head(10)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_bihar_dist_level1[['age_0_5','age_5_17','age_18_greater']])
plt.show()

# %%
df_bihar_pincode_level=df_bihar_cleaned.groupby('pincode')[['age_0_5','age_5_17','age_18_greater','total_enroll']].sum()
df_bihar_pincode_level.shape
# Out:
# (906, 4)

# %%
df_bihar_pincode_level.sort_values('total_enroll', ascending=False).reset_index()
# df_bihar_pincode_level.to_excel("df_bihar_pincode_level.xlsx")
# Out:
#      pincode  age_0_5  age_5_17  age_18_greater  total_enroll
# 0     845438     3106      4959             148          8213
# 1     843302     3613      3415             144          7172
# 2     843324     3242      2970             803          7015
# 3     845401     1524      3778              70          5372
# 4     845455     1853      2895             213          4961
# ..       ...      ...       ...             ...           ...
# 901   813124        0         1               0             1
# 902   847202        0         0               1             1
# 903   804435        1         0               0             1
# 904   823005        0         1               0             1
# 905   800005        1         0               0             1
#
# [906 rows x 5 columns]

# %%
df_bihar_pincode_level
# Out:
#          age_0_5  age_5_17  age_18_greater  total_enroll
# pincode
# 800001       479      1553             126          2158
# 800002       138       482              26           646
# 800003        22        78               4           104
# 800004       100       221              22           343
# 800005         1         0               0             1
# ...          ...       ...             ...           ...
# 855114       348       146               2           496
# 855115       996       268               4          1268
# 855116       652       189               2           843
# 855117      1049       329               2          1380
# 855456        10         3               0            13
#
# [906 rows x 4 columns]

# %%
df_bihar_pincode_level1=df_bihar_pincode_level.head(10)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_bihar_pincode_level1[['age_0_5','age_5_17','age_18_greater']])
plt.show()

# %%
bihar_month_enroll_trend=df_bihar_cleaned.groupby('month')[['age_0_5','age_5_17','age_18_greater','total_enroll']].sum()
bihar_month_enroll_trend
# Out:
#        age_0_5  age_5_17  age_18_greater  total_enroll
# month
# 03         516      1392             444          2352
# 04       12551     15361            1530         29442
# 05       13251     17159            1241         31651
# 06       16160     28223            2003         46386
# 07       19008     38019            2247         59274
# 09       62940     79583            1042        143565
# 10       46297     52921            1691        100909
# 11       48127     56444            1053        105624
# 12       44025     45700             657         90382

# %%
bihar_month_enroll_trend.to_excel("df_bihar_month_level.xlsx")

# %%
sns.lineplot(data=bihar_month_enroll_trend)
# Out:
# <Axes: xlabel='month'>

# %%
# 1. Define the folder path (same as where you read the files from)
folder_path = '/content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_enrolment/'

# 2. Choose a name for your new file
file_name = 'cleaned_enrollment_data.csv'

# 3. Combine them to create the full path
full_path = folder_path + file_name

print("File will be saved to:", full_path)
# Out:
# File will be saved to: /content/drive/MyDrive/UIDAI Hackathon 2026/api_data_aadhar_enrolment/cleaned_enrollment_data.csv

# %%
# Save the dataframe to the path defined above
# index=False prevents pandas from adding an extra row of numbers (0, 1, 2...)
enroll_1.to_csv(full_path, index=False)

print("File saved successfully!")
# Out:
# File saved successfully!

# %% [markdown]
# # **State_Wise_EDA** (On all States)

# %%
import os
import pandas as pd
import re

# ==========================================
# 1. CONFIGURATION & DATA DICTIONARIES
# ==========================================

# Define where to save the files
output_folder = '/content/drive/MyDrive/UIDAI Hackathon 2026/State_Wise_EDA/'
os.makedirs(output_folder, exist_ok=True)

# --- A. OFFICIAL DISTRICTS DICTIONARY (SOURCE OF TRUTH) ---
official_districts = {
    "Andhra Pradesh": ["Alluri Sitharama Raju", "Anakapalli", "Ananthapuramu", "Annamayya", "Bapatla", "Chittoor", "Dr. B.R. Ambedkar Konaseema", "East Godavari", "Eluru", "Guntur", "Kakinada", "Krishna", "Kurnool", "Nandyal", "NTR", "Palnadu", "Parvathipuram Manyam", "Prakasam", "Sri Potti Sriramulu Nellore", "Sri Sathya Sai", "Srikakulam", "Tirupati", "Visakhapatnam", "Vizianagaram", "West Godavari", "YSR Kadapa"],
    "Arunachal Pradesh": ["Anjaw", "Changlang", "Dibang Valley", "East Kameng", "East Siang", "Itanagar Capital Complex", "Kamle", "Kra Daadi", "Kurung Kumey", "Lepa Rada", "Lohit", "Longding", "Lower Dibang Valley", "Lower Siang", "Lower Subansiri", "Namsai", "Pakke Kessang", "Papum Pare", "Shi Yomi", "Siang", "Tawang", "Tirap", "Upper Siang", "Upper Subansiri", "West Kameng", "West Siang"],
    "Assam": ["Bajali", "Baksa", "Barpeta", "Biswanath", "Bongaigaon", "Cachar", "Charaideo", "Chirang", "Darrang", "Dhemaji", "Dhubri", "Dibrugarh", "Dima Hasao", "Goalpara", "Golaghat", "Hailakandi", "Hojai", "Jorhat", "Kamrup", "Kamrup Metropolitan", "Karbi Anglong", "Karimganj", "Kokrajhar", "Lakhimpur", "Majuli", "Morigaon", "Nagaon", "Nalbari", "Sivasagar", "Sonitpur", "South Salmara-Mankachar", "Tamulpur", "Tinsukia", "Udalguri", "West Karbi Anglong"],
    "Bihar": ["Araria", "Arwal", "Aurangabad", "Banka", "Begusarai", "Bhagalpur", "Bhojpur", "Buxar", "Darbhanga", "East Champaran", "Gaya", "Gopalganj", "Jamui", "Jehanabad", "Kaimur", "Katihar", "Khagaria", "Kishanganj", "Lakhisarai", "Madhepura", "Madhubani", "Munger", "Muzaffarpur", "Nalanda", "Nawada", "Patna", "Purnia", "Rohtas", "Saharsa", "Samastipur", "Saran", "Sheikhpura", "Sheohar", "Sitamarhi", "Siwan", "Supaul", "Vaishali", "West Champaran"],
    "Chhattisgarh": ["Balod", "Baloda Bazar", "Balrampur", "Bastar", "Bemetara", "Bijapur", "Bilaspur", "Dantewada", "Dhamtari", "Durg", "Gariaband", "Gaurela-Pendra-Marwahi", "Janjgir-Champa", "Jashpur", "Kabirdham", "Kanker", "Khairagarh-Chhuikhadan-Gandai", "Kondagaon", "Korba", "Koriya", "Mahasamund", "Manendragarh-Chirmiri-Bharatpur", "Mohla-Manpur-Ambagarh Chowki", "Mungeli", "Narayanpur", "Raigarh", "Raipur", "Rajnandgaon", "Sakti", "Sarangarh-Bilaigarh", "Sukma", "Surajpur", "Surguja"],
    "Goa": ["North Goa", "South Goa"],
    "Gujarat": ["Ahmedabad", "Amreli", "Anand", "Aravalli", "Banaskantha", "Bharuch", "Bhavnagar", "Botad", "Chhota Udepur", "Dahod", "Dang", "Devbhoomi Dwarka", "Gandhinagar", "Gir Somnath", "Jamnagar", "Junagadh", "Kheda", "Kutch", "Mahisagar", "Mehsana", "Morbi", "Narmada", "Navsari", "Panchmahal", "Patan", "Porbandar", "Rajkot", "Sabarkantha", "Surat", "Surendranagar", "Tapi", "Vadodara", "Valsad"],
    "Haryana": ["Ambala", "Bhiwani", "Charkhi Dadri", "Faridabad", "Fatehabad", "Gurugram", "Hisar", "Jhajjar", "Jind", "Kaithal", "Karnal", "Kurukshetra", "Mahendragarh", "Nuh", "Palwal", "Panchkula", "Panipat", "Rewari", "Rohtak", "Sirsa", "Sonipat", "Yamunanagar"],
    "Himachal Pradesh": ["Bilaspur", "Chamba", "Hamirpur", "Kangra", "Kinnaur", "Kullu", "Lahaul and Spiti", "Mandi", "Shimla", "Sirmaur", "Solan", "Una"],
    "Jharkhand": ["Bokaro", "Chatra", "Deoghar", "Dhanbad", "Dumka", "East Singhbhum", "Garhwa", "Giridih", "Godda", "Gumla", "Hazaribagh", "Jamtara", "Khunti", "Koderma", "Latehar", "Lohardaga", "Pakur", "Palamu", "Ramgarh", "Ranchi", "Sahibganj", "Seraikela Kharsawan", "Simdega", "West Singhbhum"],
    "Karnataka": ["Bagalkote", "Ballari", "Belagavi", "Bengaluru Rural", "Bengaluru Urban", "Bidar", "Chamarajanagar", "Chikkaballapura", "Chikkamagaluru", "Chitradurga", "Dakshina Kannada", "Davanagere", "Dharwad", "Gadag", "Hassan", "Haveri", "Kalaburagi", "Kodagu", "Kolar", "Koppal", "Mandya", "Mysuru", "Raichur", "Ramanagara", "Shivamogga", "Tumakuru", "Udupi", "Uttara Kannada", "Vijayanagara", "Vijayapura", "Yadgir"],
    "Kerala": ["Alappuzha", "Ernakulam", "Idukki", "Kannur", "Kasaragod", "Kollam", "Kottayam", "Kozhikode", "Malappuram", "Palakkad", "Pathanamthitta", "Thiruvananthapuram", "Thrissur", "Wayanad"],
    "Madhya Pradesh": ["Agar Malwa", "Alirajpur", "Anuppur", "Ashoknagar", "Balaghat", "Barwani", "Betul", "Bhind", "Bhopal", "Burhanpur", "Chhatarpur", "Chhindwara", "Damoh", "Datia", "Dewas", "Dhar", "Dindori", "Guna", "Gwalior", "Harda", "Narmadapuram", "Indore", "Jabalpur", "Jhabua", "Katni", "Khandwa", "Khargone", "Maihar", "Mandla", "Mandsaur", "Mauganj", "Morena", "Narsinghpur", "Neemuch", "Niwari", "Pandhurna", "Panna", "Raisen", "Rajgarh", "Ratlam", "Rewa", "Sagar", "Satna", "Sehore", "Seoni", "Shahdol", "Shajapur", "Sheopur", "Shivpuri", "Sidhi", "Singrauli", "Tikamgarh", "Ujjain", "Umaria", "Vidisha"],
    "Maharashtra": ["Ahmednagar", "Akola", "Amravati", "Aurangabad", "Beed", "Bhandara", "Buldhana", "Chandrapur", "Dhule", "Gadchiroli", "Gondia", "Hingoli", "Jalgaon", "Jalna", "Kolhapur", "Latur", "Mumbai City", "Mumbai Suburban", "Nagpur", "Nanded", "Nandurbar", "Nashik", "Osmanabad", "Palghar", "Parbhani", "Pune", "Raigad", "Ratnagiri", "Sangli", "Satara", "Sindhudurg", "Solapur", "Thane", "Wardha", "Washim", "Yavatmal"],
    "Manipur": ["Bishnupur", "Chandel", "Churachandpur", "Imphal East", "Imphal West", "Jiribam", "Kakching", "Kamjong", "Kangpokpi", "Noney", "Pherzawl", "Senapati", "Tamenglong", "Tengnoupal", "Thoubal", "Ukhrul"],
    "Meghalaya": ["East Garo Hills", "East Jaintia Hills", "East Khasi Hills", "Eastern West Khasi Hills", "North Garo Hills", "Ri Bhoi", "South Garo Hills", "South West Garo Hills", "South West Khasi Hills", "West Garo Hills", "West Jaintia Hills", "West Khasi Hills"],
    "Mizoram": ["Aizawl", "Champhai", "Hnahthial", "Khawzawl", "Kolasib", "Lawngtlai", "Lunglei", "Mamit", "Saiha", "Saitual", "Serchhip"],
    "Nagaland": ["Chumoukedima", "Dimapur", "Kiphire", "Kohima", "Longleng", "Mokokchung", "Mon", "Niuland", "Noklak", "Peren", "Phek", "Shamator", "Tseminyu", "Tuensang", "Wokha", "Zunheboto"],
    "Odisha": ["Angul", "Balangir", "Balasore", "Bargarh", "Bhadrak", "Boudh", "Cuttack", "Deogarh", "Dhenkanal", "Gajapati", "Ganjam", "Jagatsinghpur", "Jajpur", "Jharsuguda", "Kalahandi", "Kandhamal", "Kendrapara", "Kendujhar", "Khordha", "Koraput", "Malkangiri", "Mayurbhanj", "Nabarangpur", "Nayagarh", "Nuapada", "Puri", "Rayagada", "Sambalpur", "Subarnapur", "Sundargarh"],
    "Punjab": ["Amritsar", "Barnala", "Bathinda", "Faridkot", "Fatehgarh Sahib", "Fazilka", "Ferozepur", "Gurdaspur", "Hoshiarpur", "Jalandhar", "Kapurthala", "Ludhiana", "Malerkotla", "Mansa", "Moga", "Mohali", "Muktsar", "Nawanshahr", "Pathankot", "Patiala", "Rupnagar", "Sangrur", "Tarn Taran"],
    "Rajasthan": ["Ajmer", "Alwar", "Anupgarh", "Balotra", "Banswara", "Baran", "Barmer", "Beawar", "Bharatpur", "Bhilwara", "Bikaner", "Bundi", "Chittorgarh", "Churu", "Dausa", "Deeg", "Dholpur", "Didwana-Kuchaman", "Dudu", "Dungarpur", "Gangapur City", "Hanumangarh", "Jaipur", "Jaipur Rural", "Jaisalmer", "Jalore", "Jhalawar", "Jhunjhunu", "Jodhpur", "Jodhpur Rural", "Karauli", "Kekri", "Khairthal-Tijara", "Kota", "Kotputli-Behror", "Nagaur", "Neem Ka Thana", "Pali", "Phalodi", "Pratapgarh", "Rajsamand", "Salumbar", "Sanchore", "Sawai Madhopur", "Shahpura", "Sikar", "Sirohi", "Sri Ganganagar", "Tonk", "Udaipur"],
    "Sikkim": ["Gangtok", "Gyalshing", "Mangan", "Namchi", "Pakyong", "Soreng"],
    "Tamil Nadu": ["Ariyalur", "Chengalpattu", "Chennai", "Coimbatore", "Cuddalore", "Dharmapuri", "Dindigul", "Erode", "Kallakurichi", "Kancheepuram", "Kanniyakumari", "Karur", "Krishnagiri", "Madurai", "Mayiladuthurai", "Nagapattinam", "Namakkal", "Nilgiris", "Perambalur", "Pudukkottai", "Ramanathapuram", "Ranipet", "Salem", "Sivaganga", "Tenkasi", "Thanjavur", "Theni", "Thoothukudi", "Tiruchirappalli", "Tirunelveli", "Tirupathur", "Tiruppur", "Tiruvallur", "Tiruvannamalai", "Tiruvarur", "Vellore", "Viluppuram", "Virudhunagar"],
    "Telangana": ["Adilabad", "Bhadradri Kothagudem", "Hanumakonda", "Hyderabad", "Jagtial", "Jangaon", "Jayashankar Bhupalpally", "Jogulamba Gadwal", "Kamareddy", "Karimnagar", "Khammam", "Komaram Bheem Asifabad", "Mahabubabad", "Mahabubnagar", "Mancherial", "Medak", "Medchal-Malkajgiri", "Mulugu", "Nagarkurnool", "Nalgonda", "Narayanpet", "Nirmal", "Nizamabad", "Peddapalli", "Rajanna Sircilla", "Ranga Reddy", "Sangareddy", "Siddipet", "Suryapet", "Vikarabad", "Wanaparthy", "Warangal", "Yadadri Bhuvanagiri"],
    "Tripura": ["Dhalai", "Gomati", "Khowai", "North Tripura", "Sepahijala", "South Tripura", "Unakoti", "West Tripura"],
    "Uttar Pradesh": ["Agra", "Aligarh", "Ambedkar Nagar", "Amethi", "Amroha", "Auraiva", "Ayodhya", "Azamgarh", "Baghpat", "Bahraich", "Ballia", "Balrampur", "Banda", "Barabanki", "Bareilly", "Basti", "Bhadohi", "Bijnor", "Budaun", "Bulandshahr", "Chandauli", "Chitrakoot", "Deoria", "Etah", "Etawah", "Farrukhabad", "Fatehpur", "Firozabad", "Gautam Buddha Nagar", "Ghaziabad", "Ghazipur", "Gonda", "Gorakhpur", "Hamirpur", "Hapur", "Hardoi", "Hathras", "Jalaun", "Jaunpur", "Jhansi", "Kannauj", "Kanpur Dehat", "Kanpur Nagar", "Kasganj", "Kaushambi", "Kheri", "Kushinagar", "Lalitpur", "Lucknow", "Maharajganj", "Mahoba", "Mainpuri", "Mathura", "Mau", "Meerut", "Mirzapur", "Moradabad", "Muzaffarnagar", "Pilibhit", "Pratapgarh", "Prayagraj", "Raebareli", "Rampur", "Saharanpur", "Sambhal", "Sant Kabir Nagar", "Shahjahanpur", "Shamli", "Shravasti", "Siddharthnagar", "Sitapur", "Sonbhadra", "Sultanpur", "Unnao", "Varanasi"],
    "Uttarakhand": ["Almora", "Bageshwar", "Chamoli", "Champawat", "Dehradun", "Haridwar", "Nainital", "Pauri Garhwal", "Pithoragarh", "Rudraprayag", "Tehri Garhwal", "Udham Singh Nagar", "Uttarkashi"],
    "West Bengal": ["Alipurduar", "Bankura", "Birbhum", "Cooch Behar", "Dakshin Dinajpur", "Darjeeling", "Hooghly", "Howrah", "Jalpaiguri", "Jhargram", "Kalimpong", "Kolkata", "Malda", "Murshidabad", "Nadia", "North 24 Parganas", "Paschim Bardhaman", "Paschim Medinipur", "Purba Bardhaman", "Purba Medinipur", "Purulia", "South 24 Parganas", "Uttar Dinajpur"],
    "Jammu and Kashmir": ["Anantnag", "Bandipora", "Baramulla", "Budgam", "Doda", "Ganderbal", "Jammu", "Kathua", "Kishtwar", "Kulgam", "Kupwara", "Poonch", "Pulwama", "Rajouri", "Ramban", "Reasi", "Samba", "Shopian", "Srinagar", "Udhampur"],
    "Ladakh": ["Kargil", "Leh"],
    "Delhi": ["Central Delhi", "East Delhi", "New Delhi", "North Delhi", "North East Delhi", "North West Delhi", "Shahdara", "South Delhi", "South East Delhi", "South West Delhi", "West Delhi"],
    "Puducherry": ["Karaikal", "Mahe", "Puducherry", "Yanam"],
    "Dadra and Nagar Haveli and Daman and Diu": ["Dadra and Nagar Haveli", "Daman", "Diu"],
    "Chandigarh": ["Chandigarh"],
    "Andaman and Nicobar Islands": ["Nicobar", "North and Middle Andaman", "South Andaman"],
    "Lakshadweep": ["Lakshadweep"]
}

# --- B. MANUAL CORRECTIONS DICTIONARY (FIXING TYPOS/RENAMING) ---
manual_corrections = {
    "Andhra Pradesh": {
        "spsr nellore": "Sri Potti Sriramulu Nellore", "nellore": "Sri Potti Sriramulu Nellore",
        "visakhapatanam": "Visakhapatnam", "anantapur": "Ananthapuramu", "ananthapur": "Ananthapuramu",
        "cuddapah": "YSR Kadapa", "y. s. r": "YSR Kadapa", "n. t. r": "NTR",
        "dr. b. r. ambedkar konaseema": "Dr. B.R. Ambedkar Konaseema",
        # Fix: Remap Telangana districts found in AP data so they match valid names (will be filtered out later if not in AP list)
        "mahabub nagar": "Mahabubnagar", "mahbubnagar": "Mahabubnagar",
        "rangareddi": "Ranga Reddy", "k.v.rangareddy": "Ranga Reddy", "k.v. rangareddy": "Ranga Reddy",
        "karim nagar": "Karimnagar", "medak": "Medak", "nalgonda": "Nalgonda", "warangal": "Warangal",
        "adilabad": "Adilabad", "hyderabad": "Hyderabad", "khammam": "Khammam", "nizamabad": "Nizamabad"
    },
    "Maharashtra": {
        "ahmadnagar": "Ahmednagar", "ahmed nagar": "Ahmednagar", "ahilyanagar": "Ahmednagar",
        "washim *": "Washim", "nandurbar *": "Nandurbar", "buldana": "Buldhana",
        "gondiya": "Gondia", "gondiya *": "Gondia", "bid": "Beed",
        "raigarh": "Raigad", "raigarh(mh)": "Raigad",
        "chatrapati sambhaji nagar": "Aurangabad", "chhatrapati sambhajinagar": "Aurangabad",
        "mumbai": "Mumbai City", "mumbai(sub urban)": "Mumbai Suburban", "mumbai sub urban": "Mumbai Suburban", "mumbai suburban": "Mumbai Suburban"
    },
    "Bihar": {
        "purbi champaran": "East Champaran", "purba champaran": "East Champaran", "east champaran (motihari)": "East Champaran",
        "pashchim champaran": "West Champaran",
        "aurangabad(bh)": "Aurangabad", "purnea": "Purnia", "sheikpura": "Sheikhpura",
        "bhabua": "Kaimur", "kaimur (bhabua)": "Kaimur", "monghyr": "Munger", "samstipur": "Samastipur"
    }
}

# ==========================================
# 2. HELPER FUNCTION: CLEAN & VALIDATE
# ==========================================
def clean_and_validate_district(state_name, district_raw):
    # 1. Basic Cleaning
    if pd.isna(district_raw): return None
    clean = str(district_raw).lower().strip()
    clean = clean.replace('*', '').strip()
    clean = re.sub(r'\s+', ' ', clean)

    # 2. Apply Manual Corrections
    if state_name in manual_corrections:
        if clean in manual_corrections[state_name]:
            clean = manual_corrections[state_name][clean]

    # 3. Capitalize
    final_name = clean.title()
    if "mumbai" in clean and "sub" in clean: final_name = "Mumbai Suburban"
    if "n.t.r" in clean or "ntr" in clean: final_name = "NTR" # Case fix for NTR district

    # 4. STRICT FILTER: Check against Official List
    official_list = official_districts.get(state_name, [])

    if final_name in official_list:
        return final_name # VALID
    else:
        return None # INVALID (Delete Row)

# ==========================================
# 3. MAIN PROCESSING FUNCTION
# ==========================================
def process_and_collect_state_data(target_state):
    print(f"Processing: {target_state}...")

    # Filter Data
    state_df = df[df['state_clean'] == target_state].copy()
    if state_df.empty: return None

    # Apply Cleaning & Strict Filtering
    state_df['district_clean'] = state_df.apply(lambda x: clean_and_validate_district(target_state, x['district']), axis=1)
    state_df = state_df.dropna(subset=['district_clean']) # Delete invalids

    # Feature Engineering
    state_df['total_enroll'] = (state_df['age_0_5'] + state_df['age_5_17'] + state_df['age_18_greater'])
    state_df['new_date'] = pd.to_datetime(state_df['new_date'])
    state_df['month'] = state_df['new_date'].dt.strftime('%m')

    # SAVE 1: District Summary
    dist_sum = state_df.groupby('district_clean')[['age_0_5', 'age_5_17', 'age_18_greater', 'total_enroll']].sum().reset_index()
    dist_sum.to_csv(f"{output_folder}{target_state}_District_Summary.csv", index=False)

    # SAVE 2: Monthly Trend
    month_sum = state_df.groupby('month')[['age_0_5', 'age_5_17', 'age_18_greater', 'total_enroll']].sum().reset_index()
    month_sum.to_csv(f"{output_folder}{target_state}_Monthly_Trend.csv", index=False)

    # SAVE 3: Detailed File
    cols_to_drop = ['pin_multi_district_flag', 'is_multi_district', 'district_count', 'district', 'state']
    final_state_df = state_df.drop(columns=[c for c in cols_to_drop if c in state_df.columns], errors='ignore')
    final_state_df.to_csv(f"{output_folder}{target_state}_Detailed_Cleaned.csv", index=False)

    return final_state_df

# ==========================================
# 4. EXECUTION LOOP
# ==========================================
all_states = df['state_clean'].unique()
print(f"Starting STRICT batch processing for {len(all_states)} states...")

all_cleaned_data = []

for state in all_states:
    if pd.isna(state): continue
    try:
        if state in official_districts:
            cleaned_data = process_and_collect_state_data(state)
            if cleaned_data is not None:
                all_cleaned_data.append(cleaned_data)
        else:
            print(f"Skipping {state} (No Official List)")
    except Exception as e:
        print(f"!! Error on {state}: {e}")

# Save Master File
if all_cleaned_data:
    master_df = pd.concat(all_cleaned_data, ignore_index=True)
    master_df.to_csv('/content/drive/MyDrive/UIDAI Hackathon 2026/Master_Cleaned_Enrollment_All_States.csv', index=False)
    print("\n✅ SUCCESS! All files saved.")

# ==========================================
# 5. FINAL VERIFICATION PRINT
# ==========================================
print("\n--- FINAL VERIFICATION: CLEANED DISTRICTS PER STATE ---\n")
if all_cleaned_data:
    check_df = pd.concat(all_cleaned_data, ignore_index=True)
    for state in sorted(check_df['state_clean'].unique()):
        districts = sorted(check_df[check_df['state_clean'] == state]['district_clean'].unique())
        print(f"📍 {state.upper()} ({len(districts)}): {', '.join(districts)}")
        print("-" * 50)
# Out:
# Starting STRICT batch processing for 36 states...
# Processing: Meghalaya...
# Processing: Karnataka...
# Processing: Uttar Pradesh...
# Processing: Bihar...
# Processing: Maharashtra...
# Processing: Haryana...
# Processing: Rajasthan...
# Processing: Punjab...
# Processing: Delhi...
# Processing: Madhya Pradesh...
# Processing: West Bengal...
# Processing: Assam...
# Processing: Uttarakhand...
# Processing: Gujarat...
# Processing: Andhra Pradesh...
# Processing: Tamil Nadu...
# Processing: Chhattisgarh...
# Processing: Jharkhand...
# Processing: Nagaland...
# Processing: Manipur...
# Processing: Telangana...
# Processing: Tripura...
# Processing: Mizoram...
# Processing: Jammu and Kashmir...
# Processing: Chandigarh...
# Processing: Sikkim...
# Processing: Odisha...
# Processing: Kerala...
# Processing: Dadra and Nagar Haveli and Daman and Diu...
# Processing: Arunachal Pradesh...
# Processing: Himachal Pradesh...
# Processing: Goa...
# Processing: Ladakh...
# Processing: Andaman and Nicobar Islands...
# Processing: Puducherry...
# Processing: Lakshadweep...
#
# ✅ SUCCESS! All files saved.
#
# --- FINAL VERIFICATION: CLEANED DISTRICTS PER STATE ---
#
# 📍 ANDAMAN AND NICOBAR ISLANDS (2): Nicobar, South Andaman
# --------------------------------------------------
# 📍 ANDHRA PRADESH (24): Alluri Sitharama Raju, Anakapalli, Ananthapuramu, Annamayya, Bapatla, Chittoor, Dr. B.R. Ambedkar Konaseema, East Godavari, Eluru, Guntur, Kakinada, Krishna, Kurnool, Nandyal, Palnadu, Parvathipuram Manyam, Prakasam, Sri Potti Sriramulu Nellore, Sri Sathya Sai, Srikakulam, Tirupati, Visakhapatnam, Vizianagaram, West Godavari
# --------------------------------------------------
# 📍 ARUNACHAL PRADESH (23): Anjaw, Changlang, Dibang Valley, East Kameng, East Siang, Kamle, Kra Daadi, Kurung Kumey, Lohit, Longding, Lower Dibang Valley, Lower Siang, Lower Subansiri, Namsai, Pakke Kessang, Papum Pare, Siang, Tawang, Tirap, Upper Siang, Upper Subansiri, West Kameng, West Siang
# --------------------------------------------------
# 📍 ASSAM (31): Bajali, Baksa, Barpeta, Biswanath, Bongaigaon, Cachar, Charaideo, Chirang, Darrang, Dhemaji, Dhubri, Dibrugarh, Dima Hasao, Goalpara, Golaghat, Hailakandi, Hojai, Jorhat, Kamrup, Karbi Anglong, Karimganj, Kokrajhar, Lakhimpur, Majuli, Nagaon, Nalbari, Sivasagar, Sonitpur, Tinsukia, Udalguri, West Karbi Anglong
# --------------------------------------------------
# 📍 BIHAR (38): Araria, Arwal, Aurangabad, Banka, Begusarai, Bhagalpur, Bhojpur, Buxar, Darbhanga, East Champaran, Gaya, Gopalganj, Jamui, Jehanabad, Kaimur, Katihar, Khagaria, Kishanganj, Lakhisarai, Madhepura, Madhubani, Munger, Muzaffarpur, Nalanda, Nawada, Patna, Purnia, Rohtas, Saharsa, Samastipur, Saran, Sheikhpura, Sheohar, Sitamarhi, Siwan, Supaul, Vaishali, West Champaran
# --------------------------------------------------
# 📍 CHANDIGARH (1): Chandigarh
# --------------------------------------------------
# 📍 CHHATTISGARH (28): Balod, Baloda Bazar, Balrampur, Bastar, Bemetara, Bijapur, Bilaspur, Dantewada, Dhamtari, Durg, Gaurela-Pendra-Marwahi, Janjgir-Champa, Jashpur, Kanker, Kondagaon, Korba, Koriya, Mahasamund, Mungeli, Narayanpur, Raigarh, Raipur, Rajnandgaon, Sakti, Sarangarh-Bilaigarh, Sukma, Surajpur, Surguja
# --------------------------------------------------
# 📍 DADRA AND NAGAR HAVELI AND DAMAN AND DIU (2): Daman, Diu
# --------------------------------------------------
# 📍 DELHI (10): East Delhi, New Delhi, North Delhi, North East Delhi, North West Delhi, Shahdara, South Delhi, South East Delhi, South West Delhi, West Delhi
# --------------------------------------------------
# 📍 GOA (2): North Goa, South Goa
# --------------------------------------------------
# 📍 GUJARAT (27): Ahmedabad, Amreli, Anand, Banaskantha, Bharuch, Bhavnagar, Botad, Dahod, Dang, Gandhinagar, Gir Somnath, Jamnagar, Junagadh, Kheda, Mahisagar, Morbi, Narmada, Navsari, Patan, Porbandar, Rajkot, Sabarkantha, Surat, Surendranagar, Tapi, Vadodara, Valsad
# --------------------------------------------------
# 📍 HARYANA (22): Ambala, Bhiwani, Charkhi Dadri, Faridabad, Fatehabad, Gurugram, Hisar, Jhajjar, Jind, Kaithal, Karnal, Kurukshetra, Mahendragarh, Nuh, Palwal, Panchkula, Panipat, Rewari, Rohtak, Sirsa, Sonipat, Yamunanagar
# --------------------------------------------------
# 📍 HIMACHAL PRADESH (11): Bilaspur, Chamba, Hamirpur, Kangra, Kinnaur, Kullu, Mandi, Shimla, Sirmaur, Solan, Una
# --------------------------------------------------
# 📍 JAMMU AND KASHMIR (17): Anantnag, Budgam, Doda, Ganderbal, Jammu, Kathua, Kishtwar, Kulgam, Kupwara, Pulwama, Rajouri, Ramban, Reasi, Samba, Shopian, Srinagar, Udhampur
# --------------------------------------------------
# 📍 JHARKHAND (23): Bokaro, Chatra, Deoghar, Dhanbad, Dumka, East Singhbhum, Garhwa, Giridih, Godda, Gumla, Hazaribagh, Jamtara, Khunti, Koderma, Latehar, Lohardaga, Pakur, Palamu, Ramgarh, Ranchi, Sahibganj, Simdega, West Singhbhum
# --------------------------------------------------
# 📍 KARNATAKA (29): Ballari, Belagavi, Bengaluru Rural, Bengaluru Urban, Bidar, Chamarajanagar, Chikkamagaluru, Chitradurga, Dakshina Kannada, Davanagere, Dharwad, Gadag, Hassan, Haveri, Kalaburagi, Kodagu, Kolar, Koppal, Mandya, Mysuru, Raichur, Ramanagara, Shivamogga, Tumakuru, Udupi, Uttara Kannada, Vijayanagara, Vijayapura, Yadgir
# --------------------------------------------------
# 📍 KERALA (14): Alappuzha, Ernakulam, Idukki, Kannur, Kasaragod, Kollam, Kottayam, Kozhikode, Malappuram, Palakkad, Pathanamthitta, Thiruvananthapuram, Thrissur, Wayanad
# --------------------------------------------------
# 📍 LADAKH (2): Kargil, Leh
# --------------------------------------------------
# 📍 LAKSHADWEEP (1): Lakshadweep
# --------------------------------------------------
# 📍 MADHYA PRADESH (55): Agar Malwa, Alirajpur, Anuppur, Ashoknagar, Balaghat, Barwani, Betul, Bhind, Bhopal, Burhanpur, Chhatarpur, Chhindwara, Damoh, Datia, Dewas, Dhar, Dindori, Guna, Gwalior, Harda, Indore, Jabalpur, Jhabua, Katni, Khandwa, Khargone, Maihar, Mandla, Mandsaur, Mauganj, Morena, Narmadapuram, Narsinghpur, Neemuch, Niwari, Pandhurna, Panna, Raisen, Rajgarh, Ratlam, Rewa, Sagar, Satna, Sehore, Seoni, Shahdol, Shajapur, Sheopur, Shivpuri, Sidhi, Singrauli, Tikamgarh, Ujjain, Umaria, Vidisha
# --------------------------------------------------
# 📍 MAHARASHTRA (36): Ahmednagar, Akola, Amravati, Aurangabad, Beed, Bhandara, Buldhana, Chandrapur, Dhule, Gadchiroli, Gondia, Hingoli, Jalgaon, Jalna, Kolhapur, Latur, Mumbai City, Mumbai Suburban, Nagpur, Nanded, Nandurbar, Nashik, Osmanabad, Palghar, Parbhani, Pune, Raigad, Ratnagiri, Sangli, Satara, Sindhudurg, Solapur, Thane, Wardha, Washim, Yavatmal
# --------------------------------------------------
# 📍 MANIPUR (12): Bishnupur, Chandel, Churachandpur, Imphal East, Imphal West, Jiribam, Kakching, Pherzawl, Senapati, Tamenglong, Thoubal, Ukhrul
# --------------------------------------------------
# 📍 MEGHALAYA (12): East Garo Hills, East Jaintia Hills, East Khasi Hills, Eastern West Khasi Hills, North Garo Hills, Ri Bhoi, South Garo Hills, South West Garo Hills, South West Khasi Hills, West Garo Hills, West Jaintia Hills, West Khasi Hills
# --------------------------------------------------
# 📍 MIZORAM (11): Aizawl, Champhai, Hnahthial, Khawzawl, Kolasib, Lawngtlai, Lunglei, Mamit, Saiha, Saitual, Serchhip
# --------------------------------------------------
# 📍 NAGALAND (15): Dimapur, Kiphire, Kohima, Longleng, Mokokchung, Mon, Niuland, Noklak, Peren, Phek, Shamator, Tseminyu, Tuensang, Wokha, Zunheboto
# --------------------------------------------------
# 📍 ODISHA (28): Angul, Balangir, Bargarh, Bhadrak, Boudh, Cuttack, Dhenkanal, Gajapati, Ganjam, Jagatsinghpur, Jajpur, Jharsuguda, Kalahandi, Kandhamal, Kendrapara, Kendujhar, Khordha, Koraput, Malkangiri, Mayurbhanj, Nabarangpur, Nayagarh, Nuapada, Puri, Rayagada, Sambalpur, Subarnapur, Sundargarh
# --------------------------------------------------
# 📍 PUDUCHERRY (3): Karaikal, Puducherry, Yanam
# --------------------------------------------------
# 📍 PUNJAB (22): Amritsar, Barnala, Bathinda, Faridkot, Fatehgarh Sahib, Fazilka, Ferozepur, Gurdaspur, Hoshiarpur, Jalandhar, Kapurthala, Ludhiana, Malerkotla, Mansa, Moga, Muktsar, Nawanshahr, Pathankot, Patiala, Rupnagar, Sangrur, Tarn Taran
# --------------------------------------------------
# 📍 RAJASTHAN (37): Ajmer, Alwar, Balotra, Banswara, Baran, Barmer, Beawar, Bharatpur, Bhilwara, Bikaner, Bundi, Chittorgarh, Churu, Dausa, Deeg, Dholpur, Didwana-Kuchaman, Dungarpur, Hanumangarh, Jaipur, Jaisalmer, Jalore, Jhalawar, Jhunjhunu, Jodhpur, Karauli, Kota, Nagaur, Pali, Pratapgarh, Rajsamand, Salumbar, Sawai Madhopur, Sikar, Sirohi, Tonk, Udaipur
# --------------------------------------------------
# 📍 SIKKIM (2): Mangan, Namchi
# --------------------------------------------------
# 📍 TAMIL NADU (36): Ariyalur, Chengalpattu, Chennai, Coimbatore, Cuddalore, Dharmapuri, Dindigul, Erode, Kallakurichi, Kancheepuram, Kanniyakumari, Karur, Krishnagiri, Madurai, Mayiladuthurai, Nagapattinam, Namakkal, Perambalur, Pudukkottai, Ramanathapuram, Ranipet, Salem, Sivaganga, Tenkasi, Thanjavur, Theni, Tiruchirappalli, Tirunelveli, Tirupathur, Tiruppur, Tiruvallur, Tiruvannamalai, Tiruvarur, Vellore, Viluppuram, Virudhunagar
# --------------------------------------------------
# 📍 TELANGANA (30): Adilabad, Bhadradri Kothagudem, Hanumakonda, Hyderabad, Jangaon, Jayashankar Bhupalpally, Jogulamba Gadwal, Kamareddy, Karimnagar, Khammam, Mahabubabad, Mahabubnagar, Mancherial, Medak, Medchal-Malkajgiri, Mulugu, Nagarkurnool, Nalgonda, Narayanpet, Nirmal, Nizamabad, Peddapalli, Rajanna Sircilla, Ranga Reddy, Sangareddy, Siddipet, Suryapet, Vikarabad, Wanaparthy, Warangal
# --------------------------------------------------
# 📍 TRIPURA (8): Dhalai, Gomati, Khowai, North Tripura, Sepahijala, South Tripura, Unakoti, West Tripura
# --------------------------------------------------
# 📍 UTTAR PRADESH (74): Agra, Aligarh, Ambedkar Nagar, Amethi, Amroha, Ayodhya, Azamgarh, Baghpat, Bahraich, Ballia, Balrampur, Banda, Barabanki, Bareilly, Basti, Bhadohi, Bijnor, Budaun, Bulandshahr, Chandauli, Chitrakoot, Deoria, Etah, Etawah, Farrukhabad, Fatehpur, Firozabad, Gautam Buddha Nagar, Ghaziabad, Ghazipur, Gonda, Gorakhpur, Hamirpur, Hapur, Hardoi, Hathras, Jalaun, Jaunpur, Jhansi, Kannauj, Kanpur Dehat, Kanpur Nagar, Kasganj, Kaushambi, Kheri, Kushinagar, Lalitpur, Lucknow, Maharajganj, Mahoba, Mainpuri, Mathura, Mau, Meerut, Mirzapur, Moradabad, Muzaffarnagar, Pilibhit, Pratapgarh, Prayagraj, Raebareli, Rampur, Saharanpur, Sambhal, Sant Kabir Nagar, Shahjahanpur, Shamli, Shravasti, Siddharthnagar, Sitapur, Sonbhadra, Sultanpur, Unnao, Varanasi
# --------------------------------------------------
# 📍 UTTARAKHAND (13): Almora, Bageshwar, Chamoli, Champawat, Dehradun, Haridwar, Nainital, Pauri Garhwal, Pithoragarh, Rudraprayag, Tehri Garhwal, Udham Singh Nagar, Uttarkashi
# --------------------------------------------------
# 📍 WEST BENGAL (23): Alipurduar, Bankura, Birbhum, Cooch Behar, Dakshin Dinajpur, Darjeeling, Hooghly, Howrah, Jalpaiguri, Jhargram, Kalimpong, Kolkata, Malda, Murshidabad, Nadia, North 24 Parganas, Paschim Bardhaman, Paschim Medinipur, Purba Bardhaman, Purba Medinipur, Purulia, South 24 Parganas, Uttar Dinajpur
# --------------------------------------------------
